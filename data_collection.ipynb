# %%
# References: https://towardsdatascience.com/formula-1-race-predictor-5d4bfae887da
# We borrowed and modified the scraper coded by Veronica Nigro

import pandas as pd
import numpy as np
import requests
FROM_YEAR = 2015
THIS_YEAR = 2024

# %%
# ========================
# Get Races Info
# ========================
races = {'season': [],
        'round': [],
        'circuit_id': [],
        'circuit_name': [],
        'circuit_country': [],
        'circuit_city': [],
        'lat': [],
        'long': [],
        'date': [],
        'start_time': [],
        'url': [],
        }
for year in list(range(FROM_YEAR,THIS_YEAR)):
    # print(f"processing races year {year}")
    print(f"https://ergast.com/api/f1/{year}.json")
    url = 'https://ergast.com/api/f1/{}.json'
    r = requests.get(url.format(year))
    json = r.json()
    for item in json['MRData']['RaceTable']['Races']:
        try:
            races['season'].append(int(item['season']))
        except:
            races['season'].append(None)
        try:
            races['round'].append(int(item['round']))
        except:
            races['round'].append(None)
        try:
            races['circuit_id'].append(item['Circuit']['circuitId'])
        except:
            races['circuit_id'].append(None)
        try:
            races['circuit_name'].append(item['Circuit']['circuitName'])
        except:
            races['circuit_name'].append(None)
        try:
            races['circuit_city'].append(item['Circuit']['Location']['locality'])
        except:
            races['circuit_city'].append(None)
        try:
            races['lat'].append(float(item['Circuit']['Location']['lat']))
        except:
            races['lat'].append(None)
        try:
            races['long'].append(float(item['Circuit']['Location']['long']))
        except:
            races['long'].append(None)
        try:
            races['circuit_country'].append(item['Circuit']['Location']['country'])
        except:
            races['circuit_country'].append(None)
        try:
            races['date'].append(item['date'])
        except:
            races['date'].append(None)
        try:
            races['start_time'].append(item['time'])
        except:
            races['start_time'].append(None)
        try:
            races['url'].append(item['url'])
        except:
            races['url'].append(None)
        
races = pd.DataFrame(races)
races.to_csv("./data/races.csv", sep=",", index=False)
# append the number of rounds to each season from the races_df
# Out:
# https://ergast.com/api/f1/2015.json
# https://ergast.com/api/f1/2016.json
# https://ergast.com/api/f1/2017.json
# https://ergast.com/api/f1/2018.json
# https://ergast.com/api/f1/2019.json
# https://ergast.com/api/f1/2020.json
# https://ergast.com/api/f1/2021.json
# https://ergast.com/api/f1/2022.json
# https://ergast.com/api/f1/2023.json

# %%
races = pd.read_csv("./data/races.csv")
rounds = []
for year in np.array(races.season.unique()):
    rounds.append([year, list(races[races.season == year]['round'])])
results = {'season': [],
          'round':[],
          'circuit_id':[],
          'driver': [],
          'driver_name': [],
          'date_of_birth': [],
          'nationality': [],
          'constructor': [],
          'grid': [],
          'time': [],
          'status': [],
          'points': [],
          'podium': []}
for n in list(range(len(rounds))):
    for i in rounds[n][1]:
        # print(f"processing results round: {n}, {i}")
        print(f"http://ergast.com/api/f1/{rounds[n][0]}/{i}/results.json")
        url = 'http://ergast.com/api/f1/{}/{}/results.json'
        r = requests.get(url.format(rounds[n][0], i))
        json = r.json()
        if len(json['MRData']['RaceTable']['Races']) == 0:
            print("future event, no data")
            continue
        for item in json['MRData']['RaceTable']['Races'][0]['Results']:
            try:
                results['season'].append(int(json['MRData']['RaceTable']['Races'][0]['season']))
            except:
                results['season'].append(None)
            try:
                results['round'].append(int(json['MRData']['RaceTable']['Races'][0]['round']))
            except:
                results['round'].append(None)
            try:
                results['circuit_id'].append(json['MRData']['RaceTable']['Races'][0]['Circuit']['circuitId'])
            except:
                results['circuit_id'].append(None)
            try:
                results['driver'].append(item['Driver']['driverId'])
            except:
                results['driver'].append(None)
            try:
                results['date_of_birth'].append(item['Driver']['dateOfBirth'])
            except:
                results['date_of_birth'].append(None)   
            try:
                results['nationality'].append(item['Driver']['nationality'])
            except:
                results['nationality'].append(None)
            try:
                results['constructor'].append(item['Constructor']['constructorId'])
            except:
                results['constructor'].append(None)
            try:
                results['grid'].append(int(item['grid']))
            except:
                results['grid'].append(None)
            try:
                results['time'].append(int(item['Time']['millis']))
            except:
                results['time'].append(None)
            try:
                results['status'].append(item['status'])
            except:
                results['status'].append(None)
            try:
                results['points'].append(int(item['points']))
            except:
                results['points'].append(None)
            try:
                results['podium'].append(int(item['position']))
            except:
                results['podium'].append(None)
            try:
                dn = f"{item['Driver']['givenName']} {item['Driver']['familyName']}"
                dn = dn.lower()
                # print(dn)
                # dn = dn.replace("_", " ")
                results['driver_name'].append(dn)
            except:
                results['driver_name'].append(None)
results = pd.DataFrame(results)
results.to_csv("./data/results.csv", sep=",", index=False)
display(results)
# Out:
# http://ergast.com/api/f1/2015/1/results.json
# http://ergast.com/api/f1/2015/2/results.json
# http://ergast.com/api/f1/2015/3/results.json
# http://ergast.com/api/f1/2015/4/results.json
# http://ergast.com/api/f1/2015/5/results.json
# http://ergast.com/api/f1/2015/6/results.json
# http://ergast.com/api/f1/2015/7/results.json
# http://ergast.com/api/f1/2015/8/results.json
# http://ergast.com/api/f1/2015/9/results.json
# http://ergast.com/api/f1/2015/10/results.json
# http://ergast.com/api/f1/2015/11/results.json
# http://ergast.com/api/f1/2015/12/results.json
# http://ergast.com/api/f1/2015/13/results.json
# http://ergast.com/api/f1/2015/14/results.json
# http://ergast.com/api/f1/2015/15/results.json
# http://ergast.com/api/f1/2015/16/results.json
# http://ergast.com/api/f1/2015/17/results.json
# http://ergast.com/api/f1/2015/18/results.json
# http://ergast.com/api/f1/2015/19/results.json
# http://ergast.com/api/f1/2016/1/results.json
# http://ergast.com/api/f1/2016/2/results.json
# http://ergast.com/api/f1/2016/3/results.json
# http://ergast.com/api/f1/2016/4/results.json
# http://ergast.com/api/f1/2016/5/results.json
# http://ergast.com/api/f1/2016/6/results.json
# http://ergast.com/api/f1/2016/7/results.json
# http://ergast.com/api/f1/2016/8/results.json
# http://ergast.com/api/f1/2016/9/results.json
# http://ergast.com/api/f1/2016/10/results.json
# http://ergast.com/api/f1/2016/11/results.json
# http://ergast.com/api/f1/2016/12/results.json
# http://ergast.com/api/f1/2016/13/results.json
# http://ergast.com/api/f1/2016/14/results.json
# http://ergast.com/api/f1/2016/15/results.json
# http://ergast.com/api/f1/2016/16/results.json
# http://ergast.com/api/f1/2016/17/results.json
# http://ergast.com/api/f1/2016/18/results.json
# http://ergast.com/api/f1/2016/19/results.json
# http://ergast.com/api/f1/2016/20/results.json
# http://ergast.com/api/f1/2016/21/results.json
# http://ergast.com/api/f1/2017/1/results.json
# http://ergast.com/api/f1/2017/2/results.json
# http://ergast.com/api/f1/2017/3/results.json
# http://ergast.com/api/f1/2017/4/results.json
# http://ergast.com/api/f1/2017/5/results.json
# http://ergast.com/api/f1/2017/6/results.json
# http://ergast.com/api/f1/2017/7/results.json
# http://ergast.com/api/f1/2017/8/results.json
# http://ergast.com/api/f1/2017/9/results.json
# http://ergast.com/api/f1/2017/10/results.json
# http://ergast.com/api/f1/2017/11/results.json
# http://ergast.com/api/f1/2017/12/results.json
# http://ergast.com/api/f1/2017/13/results.json
# http://ergast.com/api/f1/2017/14/results.json
# http://ergast.com/api/f1/2017/15/results.json
# http://ergast.com/api/f1/2017/16/results.json
# http://ergast.com/api/f1/2017/17/results.json
# http://ergast.com/api/f1/2017/18/results.json
# http://ergast.com/api/f1/2017/19/results.json
# http://ergast.com/api/f1/2017/20/results.json
# http://ergast.com/api/f1/2018/1/results.json
# http://ergast.com/api/f1/2018/2/results.json
# http://ergast.com/api/f1/2018/3/results.json
# http://ergast.com/api/f1/2018/4/results.json
# http://ergast.com/api/f1/2018/5/results.json
# http://ergast.com/api/f1/2018/6/results.json
# http://ergast.com/api/f1/2018/7/results.json
# http://ergast.com/api/f1/2018/8/results.json
# http://ergast.com/api/f1/2018/9/results.json
# http://ergast.com/api/f1/2018/10/results.json
# http://ergast.com/api/f1/2018/11/results.json
# http://ergast.com/api/f1/2018/12/results.json
# http://ergast.com/api/f1/2018/13/results.json
# http://ergast.com/api/f1/2018/14/results.json
# http://ergast.com/api/f1/2018/15/results.json
# http://ergast.com/api/f1/2018/16/results.json
# http://ergast.com/api/f1/2018/17/results.json
# http://ergast.com/api/f1/2018/18/results.json
# http://ergast.com/api/f1/2018/19/results.json
# http://ergast.com/api/f1/2018/20/results.json
# http://ergast.com/api/f1/2018/21/results.json
# http://ergast.com/api/f1/2019/1/results.json
# http://ergast.com/api/f1/2019/2/results.json
# http://ergast.com/api/f1/2019/3/results.json
# http://ergast.com/api/f1/2019/4/results.json
# http://ergast.com/api/f1/2019/5/results.json
# http://ergast.com/api/f1/2019/6/results.json
# http://ergast.com/api/f1/2019/7/results.json
# http://ergast.com/api/f1/2019/8/results.json
# http://ergast.com/api/f1/2019/9/results.json
# http://ergast.com/api/f1/2019/10/results.json
# http://ergast.com/api/f1/2019/11/results.json
# http://ergast.com/api/f1/2019/12/results.json
# http://ergast.com/api/f1/2019/13/results.json
# http://ergast.com/api/f1/2019/14/results.json
# http://ergast.com/api/f1/2019/15/results.json
# http://ergast.com/api/f1/2019/16/results.json
# http://ergast.com/api/f1/2019/17/results.json
# http://ergast.com/api/f1/2019/18/results.json
# http://ergast.com/api/f1/2019/19/results.json
# http://ergast.com/api/f1/2019/20/results.json
# http://ergast.com/api/f1/2019/21/results.json
# http://ergast.com/api/f1/2020/1/results.json
# http://ergast.com/api/f1/2020/2/results.json
# http://ergast.com/api/f1/2020/3/results.json
# http://ergast.com/api/f1/2020/4/results.json
# http://ergast.com/api/f1/2020/5/results.json
# http://ergast.com/api/f1/2020/6/results.json
# http://ergast.com/api/f1/2020/7/results.json
# http://ergast.com/api/f1/2020/8/results.json
# http://ergast.com/api/f1/2020/9/results.json
# http://ergast.com/api/f1/2020/10/results.json
# http://ergast.com/api/f1/2020/11/results.json
# http://ergast.com/api/f1/2020/12/results.json
# http://ergast.com/api/f1/2020/13/results.json
# http://ergast.com/api/f1/2020/14/results.json
# http://ergast.com/api/f1/2020/15/results.json
# http://ergast.com/api/f1/2020/16/results.json
# http://ergast.com/api/f1/2020/17/results.json
# http://ergast.com/api/f1/2021/1/results.json
# http://ergast.com/api/f1/2021/2/results.json
# http://ergast.com/api/f1/2021/3/results.json
# http://ergast.com/api/f1/2021/4/results.json
# http://ergast.com/api/f1/2021/5/results.json
# http://ergast.com/api/f1/2021/6/results.json
# http://ergast.com/api/f1/2021/7/results.json
# http://ergast.com/api/f1/2021/8/results.json
# http://ergast.com/api/f1/2021/9/results.json
# http://ergast.com/api/f1/2021/10/results.json
# http://ergast.com/api/f1/2021/11/results.json
# http://ergast.com/api/f1/2021/12/results.json
# http://ergast.com/api/f1/2021/13/results.json
# http://ergast.com/api/f1/2021/14/results.json
# http://ergast.com/api/f1/2021/15/results.json
# http://ergast.com/api/f1/2021/16/results.json
# http://ergast.com/api/f1/2021/17/results.json
# http://ergast.com/api/f1/2021/18/results.json
# http://ergast.com/api/f1/2021/19/results.json
# http://ergast.com/api/f1/2021/20/results.json
# http://ergast.com/api/f1/2021/21/results.json
# http://ergast.com/api/f1/2021/22/results.json
# http://ergast.com/api/f1/2022/1/results.json
# http://ergast.com/api/f1/2022/2/results.json
# http://ergast.com/api/f1/2022/3/results.json
# http://ergast.com/api/f1/2022/4/results.json
# http://ergast.com/api/f1/2022/5/results.json
# http://ergast.com/api/f1/2022/6/results.json
# http://ergast.com/api/f1/2022/7/results.json
# http://ergast.com/api/f1/2022/8/results.json
# http://ergast.com/api/f1/2022/9/results.json
# http://ergast.com/api/f1/2022/10/results.json
# http://ergast.com/api/f1/2022/11/results.json
# http://ergast.com/api/f1/2022/12/results.json
# http://ergast.com/api/f1/2022/13/results.json
# http://ergast.com/api/f1/2022/14/results.json
# http://ergast.com/api/f1/2022/15/results.json
# http://ergast.com/api/f1/2022/16/results.json
# http://ergast.com/api/f1/2022/17/results.json
# http://ergast.com/api/f1/2022/18/results.json
# http://ergast.com/api/f1/2022/19/results.json
# http://ergast.com/api/f1/2022/20/results.json
# http://ergast.com/api/f1/2022/21/results.json
# http://ergast.com/api/f1/2022/22/results.json
# http://ergast.com/api/f1/2023/1/results.json
# http://ergast.com/api/f1/2023/2/results.json
# http://ergast.com/api/f1/2023/3/results.json
# http://ergast.com/api/f1/2023/4/results.json
# http://ergast.com/api/f1/2023/5/results.json
# http://ergast.com/api/f1/2023/6/results.json
# http://ergast.com/api/f1/2023/7/results.json
# http://ergast.com/api/f1/2023/8/results.json
# http://ergast.com/api/f1/2023/9/results.json
# http://ergast.com/api/f1/2023/10/results.json
# http://ergast.com/api/f1/2023/11/results.json
# http://ergast.com/api/f1/2023/12/results.json
# http://ergast.com/api/f1/2023/13/results.json
# http://ergast.com/api/f1/2023/14/results.json
# http://ergast.com/api/f1/2023/15/results.json
# http://ergast.com/api/f1/2023/16/results.json
# http://ergast.com/api/f1/2023/17/results.json
# http://ergast.com/api/f1/2023/18/results.json
# http://ergast.com/api/f1/2023/19/results.json
# http://ergast.com/api/f1/2023/20/results.json
# http://ergast.com/api/f1/2023/21/results.json
# http://ergast.com/api/f1/2023/22/results.json
#       season  round   circuit_id           driver       driver_name  \
# 0       2015      1  albert_park         hamilton    lewis hamilton
# 1       2015      1  albert_park          rosberg      nico rosberg
# 2       2015      1  albert_park           vettel  sebastian vettel
# 3       2015      1  albert_park            massa      felipe massa
# 4       2015      1  albert_park             nasr       felipe nasr
# ...      ...    ...          ...              ...               ...
# 3735    2023     22   yas_marina         sargeant    logan sargeant
# 3736    2023     22   yas_marina             zhou       guanyu zhou
# 3737    2023     22   yas_marina            sainz      carlos sainz
# 3738    2023     22   yas_marina           bottas   valtteri bottas
# 3739    2023     22   yas_marina  kevin_magnussen   kevin magnussen
#
#      date_of_birth nationality constructor  grid       time    status  points  \
# 0       1985-01-07     British    mercedes     1  5514067.0  Finished    25.0
# 1       1985-06-27      German    mercedes     2  5515427.0  Finished    18.0
# 2       1987-07-03      German     ferrari     4  5548590.0  Finished    15.0
# 3       1981-04-25   Brazilian    williams     3  5552263.0  Finished    12.0
# 4       1992-08-21   Brazilian      sauber    10  5609216.0  Finished    10.0
# ...            ...         ...         ...   ...        ...       ...     ...
# 3735    2000-12-31    American    williams    20  5310415.0  Finished     0.0
# 3736    1999-05-30     Chinese        alfa    19  5312046.0  Finished     0.0
# 3737    1994-09-01     Spanish     ferrari    16        NaN   Retired     0.0
# 3738    1989-08-28     Finnish        alfa    18        NaN    +1 Lap     0.0
# 3739    1992-10-05      Danish        haas    17        NaN    +1 Lap     0.0
#
#       podium
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 3735      16
# 3736      17
# 3737      18
# 3738      19
# 3739      20
#
# [3740 rows x 13 columns]

# %%
results = pd.read_csv("./data/results.csv")
driver_standings = {'season': [],
                    'round':[],
                    'driver': [],
                    'driver_points': [],
                    'driver_wins': [],
                    'driver_standings_pos': [], 
                    'constructor_name': [],
                    'constructor_country': []
                    }
for n in list(range(len(rounds))):     
    for i in rounds[n][1]:    # iterate through rounds of each year
        print(f"https://ergast.com/api/f1/{rounds[n][0]}/{i}/driverStandings.json")
        url = 'https://ergast.com/api/f1/{}/{}/driverStandings.json'
        r = requests.get(url.format(rounds[n][0], i))
        json = r.json()
        if len(json['MRData']['StandingsTable']['StandingsLists']) == 0:
            print("future event, no data")
            continue
        for item in json['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']:
            try:
                driver_standings['season'].append(int(json['MRData']['StandingsTable']['StandingsLists'][0]['season']))
            except:
                driver_standings['season'].append(None)
            try:
                driver_standings['round'].append(int(json['MRData']['StandingsTable']['StandingsLists'][0]['round']))
            except:
                driver_standings['round'].append(None)
            try:
                driver_standings['driver'].append(item['Driver']['driverId'])
            except:
                driver_standings['driver'].append(None)
            try:
                driver_standings['driver_points'].append(int(item['points']))
            except:
                driver_standings['driver_points'].append(None)
            try:
                driver_standings['driver_wins'].append(int(item['wins']))
            except:
                driver_standings['driver_wins'].append(None)
            try:
                driver_standings['driver_standings_pos'].append(int(item['position']))
            except:
                driver_standings['driver_standings_pos'].append(None)
            try:
                driver_standings['constructor_name'].append(item['Constructors'][0]['name'])
            except:
                driver_standings['constructor_name'].append(None)
            try:
                driver_standings['constructor_country'].append(item['Constructors'][0]['nationality'])
            except:
                driver_standings['constructor_country'].append(None)
driver_standings = pd.DataFrame(driver_standings)
driver_standings.to_csv("./data/driver_standings.csv", sep=",", index=False)
# display(driver_standings)
# Out:
# https://ergast.com/api/f1/2015/1/driverStandings.json
# https://ergast.com/api/f1/2015/2/driverStandings.json
# https://ergast.com/api/f1/2015/3/driverStandings.json
# https://ergast.com/api/f1/2015/4/driverStandings.json
# https://ergast.com/api/f1/2015/5/driverStandings.json
# https://ergast.com/api/f1/2015/6/driverStandings.json
# https://ergast.com/api/f1/2015/7/driverStandings.json
# https://ergast.com/api/f1/2015/8/driverStandings.json
# https://ergast.com/api/f1/2015/9/driverStandings.json
# https://ergast.com/api/f1/2015/10/driverStandings.json
# https://ergast.com/api/f1/2015/11/driverStandings.json
# https://ergast.com/api/f1/2015/12/driverStandings.json
# https://ergast.com/api/f1/2015/13/driverStandings.json
# https://ergast.com/api/f1/2015/14/driverStandings.json
# https://ergast.com/api/f1/2015/15/driverStandings.json
# https://ergast.com/api/f1/2015/16/driverStandings.json
# https://ergast.com/api/f1/2015/17/driverStandings.json
# https://ergast.com/api/f1/2015/18/driverStandings.json
# https://ergast.com/api/f1/2015/19/driverStandings.json
# https://ergast.com/api/f1/2016/1/driverStandings.json
# https://ergast.com/api/f1/2016/2/driverStandings.json
# https://ergast.com/api/f1/2016/3/driverStandings.json
# https://ergast.com/api/f1/2016/4/driverStandings.json
# https://ergast.com/api/f1/2016/5/driverStandings.json
# https://ergast.com/api/f1/2016/6/driverStandings.json
# https://ergast.com/api/f1/2016/7/driverStandings.json
# https://ergast.com/api/f1/2016/8/driverStandings.json
# https://ergast.com/api/f1/2016/9/driverStandings.json
# https://ergast.com/api/f1/2016/10/driverStandings.json
# https://ergast.com/api/f1/2016/11/driverStandings.json
# https://ergast.com/api/f1/2016/12/driverStandings.json
# https://ergast.com/api/f1/2016/13/driverStandings.json
# https://ergast.com/api/f1/2016/14/driverStandings.json
# https://ergast.com/api/f1/2016/15/driverStandings.json
# https://ergast.com/api/f1/2016/16/driverStandings.json
# https://ergast.com/api/f1/2016/17/driverStandings.json
# https://ergast.com/api/f1/2016/18/driverStandings.json
# https://ergast.com/api/f1/2016/19/driverStandings.json
# https://ergast.com/api/f1/2016/20/driverStandings.json
# https://ergast.com/api/f1/2016/21/driverStandings.json
# https://ergast.com/api/f1/2017/1/driverStandings.json
# https://ergast.com/api/f1/2017/2/driverStandings.json
# https://ergast.com/api/f1/2017/3/driverStandings.json
# https://ergast.com/api/f1/2017/4/driverStandings.json
# https://ergast.com/api/f1/2017/5/driverStandings.json
# https://ergast.com/api/f1/2017/6/driverStandings.json
# https://ergast.com/api/f1/2017/7/driverStandings.json
# https://ergast.com/api/f1/2017/8/driverStandings.json
# https://ergast.com/api/f1/2017/9/driverStandings.json
# https://ergast.com/api/f1/2017/10/driverStandings.json
# https://ergast.com/api/f1/2017/11/driverStandings.json
# https://ergast.com/api/f1/2017/12/driverStandings.json
# https://ergast.com/api/f1/2017/13/driverStandings.json
# https://ergast.com/api/f1/2017/14/driverStandings.json
# https://ergast.com/api/f1/2017/15/driverStandings.json
# https://ergast.com/api/f1/2017/16/driverStandings.json
# https://ergast.com/api/f1/2017/17/driverStandings.json
# https://ergast.com/api/f1/2017/18/driverStandings.json
# https://ergast.com/api/f1/2017/19/driverStandings.json
# https://ergast.com/api/f1/2017/20/driverStandings.json
# https://ergast.com/api/f1/2018/1/driverStandings.json
# https://ergast.com/api/f1/2018/2/driverStandings.json
# https://ergast.com/api/f1/2018/3/driverStandings.json
# https://ergast.com/api/f1/2018/4/driverStandings.json
# https://ergast.com/api/f1/2018/5/driverStandings.json
# https://ergast.com/api/f1/2018/6/driverStandings.json
# https://ergast.com/api/f1/2018/7/driverStandings.json
# https://ergast.com/api/f1/2018/8/driverStandings.json
# https://ergast.com/api/f1/2018/9/driverStandings.json
# https://ergast.com/api/f1/2018/10/driverStandings.json
# https://ergast.com/api/f1/2018/11/driverStandings.json
# https://ergast.com/api/f1/2018/12/driverStandings.json
# https://ergast.com/api/f1/2018/13/driverStandings.json
# https://ergast.com/api/f1/2018/14/driverStandings.json
# https://ergast.com/api/f1/2018/15/driverStandings.json
# https://ergast.com/api/f1/2018/16/driverStandings.json
# https://ergast.com/api/f1/2018/17/driverStandings.json
# https://ergast.com/api/f1/2018/18/driverStandings.json
# https://ergast.com/api/f1/2018/19/driverStandings.json
# https://ergast.com/api/f1/2018/20/driverStandings.json
# https://ergast.com/api/f1/2018/21/driverStandings.json
# https://ergast.com/api/f1/2019/1/driverStandings.json
# https://ergast.com/api/f1/2019/2/driverStandings.json
# https://ergast.com/api/f1/2019/3/driverStandings.json
# https://ergast.com/api/f1/2019/4/driverStandings.json
# https://ergast.com/api/f1/2019/5/driverStandings.json
# https://ergast.com/api/f1/2019/6/driverStandings.json
# https://ergast.com/api/f1/2019/7/driverStandings.json
# https://ergast.com/api/f1/2019/8/driverStandings.json
# https://ergast.com/api/f1/2019/9/driverStandings.json
# https://ergast.com/api/f1/2019/10/driverStandings.json
# https://ergast.com/api/f1/2019/11/driverStandings.json
# https://ergast.com/api/f1/2019/12/driverStandings.json
# https://ergast.com/api/f1/2019/13/driverStandings.json
# https://ergast.com/api/f1/2019/14/driverStandings.json
# https://ergast.com/api/f1/2019/15/driverStandings.json
# https://ergast.com/api/f1/2019/16/driverStandings.json
# https://ergast.com/api/f1/2019/17/driverStandings.json
# https://ergast.com/api/f1/2019/18/driverStandings.json
# https://ergast.com/api/f1/2019/19/driverStandings.json
# https://ergast.com/api/f1/2019/20/driverStandings.json
# https://ergast.com/api/f1/2019/21/driverStandings.json
# https://ergast.com/api/f1/2020/1/driverStandings.json
# https://ergast.com/api/f1/2020/2/driverStandings.json
# https://ergast.com/api/f1/2020/3/driverStandings.json
# https://ergast.com/api/f1/2020/4/driverStandings.json
# https://ergast.com/api/f1/2020/5/driverStandings.json
# https://ergast.com/api/f1/2020/6/driverStandings.json
# https://ergast.com/api/f1/2020/7/driverStandings.json
# https://ergast.com/api/f1/2020/8/driverStandings.json
# https://ergast.com/api/f1/2020/9/driverStandings.json
# https://ergast.com/api/f1/2020/10/driverStandings.json
# https://ergast.com/api/f1/2020/11/driverStandings.json
# https://ergast.com/api/f1/2020/12/driverStandings.json
# https://ergast.com/api/f1/2020/13/driverStandings.json
# https://ergast.com/api/f1/2020/14/driverStandings.json
# https://ergast.com/api/f1/2020/15/driverStandings.json
# https://ergast.com/api/f1/2020/16/driverStandings.json
# https://ergast.com/api/f1/2020/17/driverStandings.json
# https://ergast.com/api/f1/2021/1/driverStandings.json
# https://ergast.com/api/f1/2021/2/driverStandings.json
# https://ergast.com/api/f1/2021/3/driverStandings.json
# https://ergast.com/api/f1/2021/4/driverStandings.json
# https://ergast.com/api/f1/2021/5/driverStandings.json
# https://ergast.com/api/f1/2021/6/driverStandings.json
# https://ergast.com/api/f1/2021/7/driverStandings.json
# https://ergast.com/api/f1/2021/8/driverStandings.json
# https://ergast.com/api/f1/2021/9/driverStandings.json
# https://ergast.com/api/f1/2021/10/driverStandings.json
# https://ergast.com/api/f1/2021/11/driverStandings.json
# https://ergast.com/api/f1/2021/12/driverStandings.json
# https://ergast.com/api/f1/2021/13/driverStandings.json
# https://ergast.com/api/f1/2021/14/driverStandings.json
# https://ergast.com/api/f1/2021/15/driverStandings.json
# https://ergast.com/api/f1/2021/16/driverStandings.json
# https://ergast.com/api/f1/2021/17/driverStandings.json
# https://ergast.com/api/f1/2021/18/driverStandings.json
# https://ergast.com/api/f1/2021/19/driverStandings.json
# https://ergast.com/api/f1/2021/20/driverStandings.json
# https://ergast.com/api/f1/2021/21/driverStandings.json
# https://ergast.com/api/f1/2021/22/driverStandings.json
# https://ergast.com/api/f1/2022/1/driverStandings.json
# https://ergast.com/api/f1/2022/2/driverStandings.json
# https://ergast.com/api/f1/2022/3/driverStandings.json
# https://ergast.com/api/f1/2022/4/driverStandings.json
# https://ergast.com/api/f1/2022/5/driverStandings.json
# https://ergast.com/api/f1/2022/6/driverStandings.json
# https://ergast.com/api/f1/2022/7/driverStandings.json
# https://ergast.com/api/f1/2022/8/driverStandings.json
# https://ergast.com/api/f1/2022/9/driverStandings.json
# https://ergast.com/api/f1/2022/10/driverStandings.json
# https://ergast.com/api/f1/2022/11/driverStandings.json
# https://ergast.com/api/f1/2022/12/driverStandings.json
# https://ergast.com/api/f1/2022/13/driverStandings.json
# https://ergast.com/api/f1/2022/14/driverStandings.json
# https://ergast.com/api/f1/2022/15/driverStandings.json
# https://ergast.com/api/f1/2022/16/driverStandings.json
# https://ergast.com/api/f1/2022/17/driverStandings.json
# https://ergast.com/api/f1/2022/18/driverStandings.json
# https://ergast.com/api/f1/2022/19/driverStandings.json
# https://ergast.com/api/f1/2022/20/driverStandings.json
# https://ergast.com/api/f1/2022/21/driverStandings.json
# https://ergast.com/api/f1/2022/22/driverStandings.json
# https://ergast.com/api/f1/2023/1/driverStandings.json
# https://ergast.com/api/f1/2023/2/driverStandings.json
# https://ergast.com/api/f1/2023/3/driverStandings.json
# https://ergast.com/api/f1/2023/4/driverStandings.json
# https://ergast.com/api/f1/2023/5/driverStandings.json
# https://ergast.com/api/f1/2023/6/driverStandings.json
# https://ergast.com/api/f1/2023/7/driverStandings.json
# https://ergast.com/api/f1/2023/8/driverStandings.json
# https://ergast.com/api/f1/2023/9/driverStandings.json
# https://ergast.com/api/f1/2023/10/driverStandings.json
# https://ergast.com/api/f1/2023/11/driverStandings.json
# https://ergast.com/api/f1/2023/12/driverStandings.json
# https://ergast.com/api/f1/2023/13/driverStandings.json
# https://ergast.com/api/f1/2023/14/driverStandings.json
# https://ergast.com/api/f1/2023/15/driverStandings.json
# https://ergast.com/api/f1/2023/16/driverStandings.json
# https://ergast.com/api/f1/2023/17/driverStandings.json
# https://ergast.com/api/f1/2023/18/driverStandings.json
# https://ergast.com/api/f1/2023/19/driverStandings.json
# https://ergast.com/api/f1/2023/20/driverStandings.json
# https://ergast.com/api/f1/2023/21/driverStandings.json
# https://ergast.com/api/f1/2023/22/driverStandings.json

# %%
driver_standings = pd.read_csv("./data/driver_standings.csv")
# define lookup function to shift points and number of wins from previous rounds
def lookup (df, team, points):
    df['lookup1'] = df.season.astype(str) + df[team] + df['round'].astype(str)
    df['lookup2'] = df.season.astype(str) + df[team] + (df['round']-1).astype(str)
    new_df = df.merge(df[['lookup1', points]], how = 'left', left_on='lookup2',right_on='lookup1')
    new_df.drop(['lookup1_x', 'lookup2', 'lookup1_y'], axis = 1, inplace = True)
    new_df.rename(columns = {points+'_x': points+'_after_race', points+'_y': points}, inplace = True)
    new_df[points].fillna(0, inplace = True)
    return new_df
driver_standings = lookup(driver_standings, 'driver', 'driver_points')
driver_standings = lookup(driver_standings, 'driver', 'driver_wins')
driver_standings = lookup(driver_standings, 'driver', 'driver_standings_pos')
driver_standings.drop(['driver_points_after_race', 'driver_wins_after_race', 'driver_standings_pos_after_race'], 
                      axis = 1, inplace = True)
constructor_rounds = rounds[:]
constructor_standings = {'season': [],
                    'round':[],
                    'constructor': [],
                    'constructor_points': [],
                    'constructor_wins': [],
                    'constructor_standings_pos': [],
                    }
for n in list(range(len(constructor_rounds))):
    for i in constructor_rounds[n][1]:
        print(f"https://ergast.com/api/f1/{constructor_rounds[n][0]}/{i}/constructorStandings.json")
        url = 'https://ergast.com/api/f1/{}/{}/constructorStandings.json'
        r = requests.get(url.format(constructor_rounds[n][0], i))
        json = r.json()
        if len(json['MRData']['StandingsTable']['StandingsLists']) == 0:
            print("future event, no data")
            continue
        for item in json['MRData']['StandingsTable']['StandingsLists'][0]['ConstructorStandings']:
            try:
                constructor_standings['season'].append(int(json['MRData']['StandingsTable']['StandingsLists'][0]['season']))
            except:
                constructor_standings['season'].append(None)
            try:
                constructor_standings['round'].append(int(json['MRData']['StandingsTable']['StandingsLists'][0]['round']))
            except:
                constructor_standings['round'].append(None)
            try:
                constructor_standings['constructor'].append(item['Constructor']['constructorId'])
            except:
                constructor_standings['constructor'].append(None)
            try:
                constructor_standings['constructor_points'].append(int(item['points']))
            except:
                constructor_standings['constructor_points'].append(None)
            try:
                constructor_standings['constructor_wins'].append(int(item['wins']))
            except:
                constructor_standings['constructor_wins'].append(None)
            try:
                constructor_standings['constructor_standings_pos'].append(int(item['position']))
            except:
                constructor_standings['constructor_standings_pos'].append(None)
constructor_standings = pd.DataFrame(constructor_standings)
constructor_standings = lookup(constructor_standings, 'constructor', 'constructor_points')
constructor_standings = lookup(constructor_standings, 'constructor', 'constructor_wins')
constructor_standings = lookup(constructor_standings, 'constructor', 'constructor_standings_pos')
constructor_standings.drop(['constructor_points_after_race', 'constructor_wins_after_race','constructor_standings_pos_after_race' ],
                           axis = 1, inplace = True)
constructor_standings.to_csv("./data/constructor_standings.csv", sep=",", index=False)
# Out:
# https://ergast.com/api/f1/2015/1/constructorStandings.json
# https://ergast.com/api/f1/2015/2/constructorStandings.json
# https://ergast.com/api/f1/2015/3/constructorStandings.json
# https://ergast.com/api/f1/2015/4/constructorStandings.json
# https://ergast.com/api/f1/2015/5/constructorStandings.json
# https://ergast.com/api/f1/2015/6/constructorStandings.json
# https://ergast.com/api/f1/2015/7/constructorStandings.json
# https://ergast.com/api/f1/2015/8/constructorStandings.json
# https://ergast.com/api/f1/2015/9/constructorStandings.json
# https://ergast.com/api/f1/2015/10/constructorStandings.json
# https://ergast.com/api/f1/2015/11/constructorStandings.json
# https://ergast.com/api/f1/2015/12/constructorStandings.json
# https://ergast.com/api/f1/2015/13/constructorStandings.json
# https://ergast.com/api/f1/2015/14/constructorStandings.json
# https://ergast.com/api/f1/2015/15/constructorStandings.json
# https://ergast.com/api/f1/2015/16/constructorStandings.json
# https://ergast.com/api/f1/2015/17/constructorStandings.json
# https://ergast.com/api/f1/2015/18/constructorStandings.json
# https://ergast.com/api/f1/2015/19/constructorStandings.json
# https://ergast.com/api/f1/2016/1/constructorStandings.json
# https://ergast.com/api/f1/2016/2/constructorStandings.json
# https://ergast.com/api/f1/2016/3/constructorStandings.json
# https://ergast.com/api/f1/2016/4/constructorStandings.json
# https://ergast.com/api/f1/2016/5/constructorStandings.json
# https://ergast.com/api/f1/2016/6/constructorStandings.json
# https://ergast.com/api/f1/2016/7/constructorStandings.json
# https://ergast.com/api/f1/2016/8/constructorStandings.json
# https://ergast.com/api/f1/2016/9/constructorStandings.json
# https://ergast.com/api/f1/2016/10/constructorStandings.json
# https://ergast.com/api/f1/2016/11/constructorStandings.json
# https://ergast.com/api/f1/2016/12/constructorStandings.json
# https://ergast.com/api/f1/2016/13/constructorStandings.json
# https://ergast.com/api/f1/2016/14/constructorStandings.json
# https://ergast.com/api/f1/2016/15/constructorStandings.json
# https://ergast.com/api/f1/2016/16/constructorStandings.json
# https://ergast.com/api/f1/2016/17/constructorStandings.json
# https://ergast.com/api/f1/2016/18/constructorStandings.json
# https://ergast.com/api/f1/2016/19/constructorStandings.json
# https://ergast.com/api/f1/2016/20/constructorStandings.json
# https://ergast.com/api/f1/2016/21/constructorStandings.json
# https://ergast.com/api/f1/2017/1/constructorStandings.json
# https://ergast.com/api/f1/2017/2/constructorStandings.json
# https://ergast.com/api/f1/2017/3/constructorStandings.json
# https://ergast.com/api/f1/2017/4/constructorStandings.json
# https://ergast.com/api/f1/2017/5/constructorStandings.json
# https://ergast.com/api/f1/2017/6/constructorStandings.json
# https://ergast.com/api/f1/2017/7/constructorStandings.json
# https://ergast.com/api/f1/2017/8/constructorStandings.json
# https://ergast.com/api/f1/2017/9/constructorStandings.json
# https://ergast.com/api/f1/2017/10/constructorStandings.json
# https://ergast.com/api/f1/2017/11/constructorStandings.json
# https://ergast.com/api/f1/2017/12/constructorStandings.json
# https://ergast.com/api/f1/2017/13/constructorStandings.json
# https://ergast.com/api/f1/2017/14/constructorStandings.json
# https://ergast.com/api/f1/2017/15/constructorStandings.json
# https://ergast.com/api/f1/2017/16/constructorStandings.json
# https://ergast.com/api/f1/2017/17/constructorStandings.json
# https://ergast.com/api/f1/2017/18/constructorStandings.json
# https://ergast.com/api/f1/2017/19/constructorStandings.json
# https://ergast.com/api/f1/2017/20/constructorStandings.json
# https://ergast.com/api/f1/2018/1/constructorStandings.json
# https://ergast.com/api/f1/2018/2/constructorStandings.json
# https://ergast.com/api/f1/2018/3/constructorStandings.json
# https://ergast.com/api/f1/2018/4/constructorStandings.json
# https://ergast.com/api/f1/2018/5/constructorStandings.json
# https://ergast.com/api/f1/2018/6/constructorStandings.json
# https://ergast.com/api/f1/2018/7/constructorStandings.json
# https://ergast.com/api/f1/2018/8/constructorStandings.json
# https://ergast.com/api/f1/2018/9/constructorStandings.json
# https://ergast.com/api/f1/2018/10/constructorStandings.json
# https://ergast.com/api/f1/2018/11/constructorStandings.json
# https://ergast.com/api/f1/2018/12/constructorStandings.json
# https://ergast.com/api/f1/2018/13/constructorStandings.json
# https://ergast.com/api/f1/2018/14/constructorStandings.json
# https://ergast.com/api/f1/2018/15/constructorStandings.json
# https://ergast.com/api/f1/2018/16/constructorStandings.json
# https://ergast.com/api/f1/2018/17/constructorStandings.json
# https://ergast.com/api/f1/2018/18/constructorStandings.json
# https://ergast.com/api/f1/2018/19/constructorStandings.json
# https://ergast.com/api/f1/2018/20/constructorStandings.json
# https://ergast.com/api/f1/2018/21/constructorStandings.json
# https://ergast.com/api/f1/2019/1/constructorStandings.json
# https://ergast.com/api/f1/2019/2/constructorStandings.json
# https://ergast.com/api/f1/2019/3/constructorStandings.json
# https://ergast.com/api/f1/2019/4/constructorStandings.json
# https://ergast.com/api/f1/2019/5/constructorStandings.json
# https://ergast.com/api/f1/2019/6/constructorStandings.json
# https://ergast.com/api/f1/2019/7/constructorStandings.json
# https://ergast.com/api/f1/2019/8/constructorStandings.json
# https://ergast.com/api/f1/2019/9/constructorStandings.json
# https://ergast.com/api/f1/2019/10/constructorStandings.json
# https://ergast.com/api/f1/2019/11/constructorStandings.json
# https://ergast.com/api/f1/2019/12/constructorStandings.json
# https://ergast.com/api/f1/2019/13/constructorStandings.json
# https://ergast.com/api/f1/2019/14/constructorStandings.json
# https://ergast.com/api/f1/2019/15/constructorStandings.json
# https://ergast.com/api/f1/2019/16/constructorStandings.json
# https://ergast.com/api/f1/2019/17/constructorStandings.json
# https://ergast.com/api/f1/2019/18/constructorStandings.json
# https://ergast.com/api/f1/2019/19/constructorStandings.json
# https://ergast.com/api/f1/2019/20/constructorStandings.json
# https://ergast.com/api/f1/2019/21/constructorStandings.json
# https://ergast.com/api/f1/2020/1/constructorStandings.json
# https://ergast.com/api/f1/2020/2/constructorStandings.json
# https://ergast.com/api/f1/2020/3/constructorStandings.json
# https://ergast.com/api/f1/2020/4/constructorStandings.json
# https://ergast.com/api/f1/2020/5/constructorStandings.json
# https://ergast.com/api/f1/2020/6/constructorStandings.json
# https://ergast.com/api/f1/2020/7/constructorStandings.json
# https://ergast.com/api/f1/2020/8/constructorStandings.json
# https://ergast.com/api/f1/2020/9/constructorStandings.json
# https://ergast.com/api/f1/2020/10/constructorStandings.json
# https://ergast.com/api/f1/2020/11/constructorStandings.json
# https://ergast.com/api/f1/2020/12/constructorStandings.json
# https://ergast.com/api/f1/2020/13/constructorStandings.json
# https://ergast.com/api/f1/2020/14/constructorStandings.json
# https://ergast.com/api/f1/2020/15/constructorStandings.json
# https://ergast.com/api/f1/2020/16/constructorStandings.json
# https://ergast.com/api/f1/2020/17/constructorStandings.json
# https://ergast.com/api/f1/2021/1/constructorStandings.json
# https://ergast.com/api/f1/2021/2/constructorStandings.json
# https://ergast.com/api/f1/2021/3/constructorStandings.json
# https://ergast.com/api/f1/2021/4/constructorStandings.json
# https://ergast.com/api/f1/2021/5/constructorStandings.json
# https://ergast.com/api/f1/2021/6/constructorStandings.json
# https://ergast.com/api/f1/2021/7/constructorStandings.json
# https://ergast.com/api/f1/2021/8/constructorStandings.json
# https://ergast.com/api/f1/2021/9/constructorStandings.json
# https://ergast.com/api/f1/2021/10/constructorStandings.json
# https://ergast.com/api/f1/2021/11/constructorStandings.json
# https://ergast.com/api/f1/2021/12/constructorStandings.json
# https://ergast.com/api/f1/2021/13/constructorStandings.json
# https://ergast.com/api/f1/2021/14/constructorStandings.json
# https://ergast.com/api/f1/2021/15/constructorStandings.json
# https://ergast.com/api/f1/2021/16/constructorStandings.json
# https://ergast.com/api/f1/2021/17/constructorStandings.json
# https://ergast.com/api/f1/2021/18/constructorStandings.json
# https://ergast.com/api/f1/2021/19/constructorStandings.json
# https://ergast.com/api/f1/2021/20/constructorStandings.json
# https://ergast.com/api/f1/2021/21/constructorStandings.json
# https://ergast.com/api/f1/2021/22/constructorStandings.json
# https://ergast.com/api/f1/2022/1/constructorStandings.json
# https://ergast.com/api/f1/2022/2/constructorStandings.json
# https://ergast.com/api/f1/2022/3/constructorStandings.json
# https://ergast.com/api/f1/2022/4/constructorStandings.json
# https://ergast.com/api/f1/2022/5/constructorStandings.json
# https://ergast.com/api/f1/2022/6/constructorStandings.json
# https://ergast.com/api/f1/2022/7/constructorStandings.json
# https://ergast.com/api/f1/2022/8/constructorStandings.json
# https://ergast.com/api/f1/2022/9/constructorStandings.json
# https://ergast.com/api/f1/2022/10/constructorStandings.json
# https://ergast.com/api/f1/2022/11/constructorStandings.json
# https://ergast.com/api/f1/2022/12/constructorStandings.json
# https://ergast.com/api/f1/2022/13/constructorStandings.json
# https://ergast.com/api/f1/2022/14/constructorStandings.json
# https://ergast.com/api/f1/2022/15/constructorStandings.json
# https://ergast.com/api/f1/2022/16/constructorStandings.json
# https://ergast.com/api/f1/2022/17/constructorStandings.json
# https://ergast.com/api/f1/2022/18/constructorStandings.json
# https://ergast.com/api/f1/2022/19/constructorStandings.json
# https://ergast.com/api/f1/2022/20/constructorStandings.json
# https://ergast.com/api/f1/2022/21/constructorStandings.json
# https://ergast.com/api/f1/2022/22/constructorStandings.json
# https://ergast.com/api/f1/2023/1/constructorStandings.json
# https://ergast.com/api/f1/2023/2/constructorStandings.json
# https://ergast.com/api/f1/2023/3/constructorStandings.json
# https://ergast.com/api/f1/2023/4/constructorStandings.json
# https://ergast.com/api/f1/2023/5/constructorStandings.json
# https://ergast.com/api/f1/2023/6/constructorStandings.json
# https://ergast.com/api/f1/2023/7/constructorStandings.json
# https://ergast.com/api/f1/2023/8/constructorStandings.json
# https://ergast.com/api/f1/2023/9/constructorStandings.json
# https://ergast.com/api/f1/2023/10/constructorStandings.json
# https://ergast.com/api/f1/2023/11/constructorStandings.json
# https://ergast.com/api/f1/2023/12/constructorStandings.json
# https://ergast.com/api/f1/2023/13/constructorStandings.json
# https://ergast.com/api/f1/2023/14/constructorStandings.json
# https://ergast.com/api/f1/2023/15/constructorStandings.json
# https://ergast.com/api/f1/2023/16/constructorStandings.json
# https://ergast.com/api/f1/2023/17/constructorStandings.json
# https://ergast.com/api/f1/2023/18/constructorStandings.json
# https://ergast.com/api/f1/2023/19/constructorStandings.json
# https://ergast.com/api/f1/2023/20/constructorStandings.json
# https://ergast.com/api/f1/2023/21/constructorStandings.json
# https://ergast.com/api/f1/2023/22/constructorStandings.json

# %%
# This scraper has deprecated or we may have been denied access. Do not run this snippet of code or it will purge our existing qualifying_results.csv 
constructor_standings = pd.read_csv("./data/constructor_standings.csv")
# ==========
# Qualifying Results
# ==========
from bs4 import BeautifulSoup
def time_to_milliseconds(time_str):
    milliseconds = np.nan
    try:
        parts = time_str.split(':')
        milliseconds = 0
        if len(parts) == 3:
            # Format is hours:minutes:seconds.milliseconds
            hours, minutes, seconds = parts
            milliseconds += int(hours) * 3600000  # Convert hours to milliseconds
            milliseconds += int(minutes) * 60000  # Convert minutes to milliseconds
        elif len(parts) == 2:
            # Format is minutes:seconds.milliseconds
            minutes, seconds = parts
            milliseconds += int(minutes) * 60000  # Convert minutes to milliseconds
        else:
            raise ValueError("Invalid time format")
        # Splitting seconds and milliseconds and converting
        seconds, msec = seconds.split('.')
        milliseconds += int(seconds) * 1000  # Convert seconds to milliseconds
        milliseconds += int(msec)  # Add milliseconds
    except:
        print("time to milli error")
    return milliseconds

def reformat_name(name):
    name = name.replace("-", " ")
    name = name.lower()
    return name

qualifying_results = pd.DataFrame()
# Qualifying times are only available from 1983
for year in list(range(FROM_YEAR,THIS_YEAR)):
    url = 'https://www.formula1.com/en/results.html/{}/races.html'
    r = requests.get(url.format(year))
    soup = BeautifulSoup(r.text, 'html.parser')
    # find links to all circuits for a certain year
    year_links = []
    for page in soup.find_all('a', attrs = {'class':"resultsarchive-filter-item-link FilterTrigger"}):
        link = page.get('href')
        if f'/en/results.html/{year}/races/' in link: 
            year_links.append(link)
    # for each circuit, switch to the starting grid page and read table
    year_df = pd.DataFrame()
    new_url = 'https://www.formula1.com{}'
    for n, link in list(enumerate(year_links)):
        link = link.replace('race-result.html', 'starting-grid.html')
        print(f"https://www.formula1.com{link}")
        try:
            df = pd.read_html(new_url.format(link))
        except:
            print("data not yet available")
            continue
        df = df[0]
        df['season'] = year
        df['round'] = n+1
        for col in df:
            if 'Unnamed' in col:
                df.drop(col, axis = 1, inplace = True)
        year_df = pd.concat([year_df, df])
    # concatenate all tables from all years  
    qualifying_results = pd.concat([qualifying_results, year_df])
# rename columns
qualifying_results.rename(columns = {'Pos': 'grid', 'Driver': 'driver_name', 'Car': 'car',
                                     'Time': 'qualifying_time'}, inplace = True)
# drop driver number column
# qualifying_results.drop(['No', 'Gap', 'Laps'], axis = 1, inplace = True)
qualifying_results.drop(['No'], axis = 1, inplace = True)
qualifying_results['driver_name'] = qualifying_results['driver_name'].str.split().apply(lambda x: ' '.join(x[:-1]))
qualifying_results['driver_name'] = qualifying_results['driver_name'].apply(reformat_name)
# qualifying_results['qualifying_time'] = qualifying_results['qualifying_time'].apply(time_to_milliseconds)
qualifying_results.drop(['qualifying_time'], axis = 1, inplace = True)
qualifying_results.to_csv("./data/qualifying_results.csv", sep=",", index=False)
display(qualifying_results)
# Out:
# https://www.formula1.com/en/results.html/2015/races/917/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/918/malaysia/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/919/china/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/920/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/921/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/922/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/923/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/924/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/925/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/927/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/928/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/929/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/930/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/931/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/932/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/933/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/934/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/935/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2015/races/936/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/938/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/939/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/940/china/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/941/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/942/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/943/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/944/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/958/europe/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/945/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/946/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/947/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/948/germany/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/949/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/950/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/951/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/952/malaysia/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/953/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/954/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/955/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/956/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2016/races/957/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/959/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/960/china/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/961/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/962/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/963/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/964/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/965/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/966/azerbaijan/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/967/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/968/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/969/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/970/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/971/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/972/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/973/malaysia/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/974/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/975/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/976/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/977/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2017/races/978/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/979/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/980/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/981/china/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/982/azerbaijan/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/983/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/984/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/985/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/986/france/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/987/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/988/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/989/germany/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/990/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/991/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/992/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/993/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/994/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/995/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/996/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/997/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/998/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2018/races/999/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1000/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1001/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1002/china/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1003/azerbaijan/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1004/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1005/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1006/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1007/france/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1008/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1009/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1010/germany/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1011/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1012/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1013/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1014/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1015/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1016/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1017/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1018/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1019/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2019/races/1020/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1045/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1046/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1047/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1048/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1049/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1050/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1051/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1052/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1053/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1054/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1055/germany/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1056/portugal/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1057/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1058/turkey/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1059/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1060/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2020/races/1061/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1064/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1065/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1066/portugal/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1086/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1067/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1068/azerbaijan/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1070/france/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1092/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1071/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1072/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1073/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1074/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1075/netherlands/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1076/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1077/russia/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1078/turkey/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1102/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1103/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1104/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1105/qatar/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1106/saudi-arabia/starting-grid.html
# https://www.formula1.com/en/results.html/2021/races/1107/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1124/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1125/saudi-arabia/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1108/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1109/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1110/miami/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1111/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1112/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1126/azerbaijan/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1113/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1114/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1115/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1116/france/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1117/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1118/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1119/netherlands/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1120/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1133/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1134/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1135/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1136/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1137/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2022/races/1138/abu-dhabi/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1141/bahrain/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1142/saudi-arabia/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1143/australia/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1207/azerbaijan/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1208/miami/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1209/italy/starting-grid.html
# data not yet available
# https://www.formula1.com/en/results.html/2023/races/1210/monaco/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1211/spain/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1212/canada/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1213/austria/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1214/great-britain/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1215/hungary/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1216/belgium/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1217/netherlands/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1218/italy/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1219/singapore/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1220/japan/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1221/qatar/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1222/united-states/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1223/mexico/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1224/brazil/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1225/las-vegas/starting-grid.html
# https://www.formula1.com/en/results.html/2023/races/1226/abu-dhabi/starting-grid.html
#     grid       driver_name                 car  season  round
# 0      1    lewis hamilton            Mercedes    2015      1
# 1      2      nico rosberg            Mercedes    2015      1
# 2      3      felipe massa   Williams Mercedes    2015      1
# 3      4  sebastian vettel             Ferrari    2015      1
# 4      5    kimi räikkönen             Ferrari    2015      1
# ..   ...               ...                 ...     ...    ...
# 15    16      carlos sainz             Ferrari    2023     23
# 16    17   kevin magnussen        Haas Ferrari    2023     23
# 17    18   valtteri bottas  Alfa Romeo Ferrari    2023     23
# 18    19       zhou guanyu  Alfa Romeo Ferrari    2023     23
# 19    20    logan sargeant   Williams Mercedes    2023     23
#
# [3705 rows x 5 columns]

# %%
constructor_standings = pd.read_csv("./data/constructor_standings.csv")
qualifying_results = pd.read_csv("./data/qualifying_results.csv")
# ============
# Weather
# ============
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import requests
from bs4 import BeautifulSoup
races = pd.read_csv("./data/races.csv")
# races = races.iloc[:10]
weather = races.iloc[:,[0,1,2]]
print(len(weather))
info = []
# read wikipedia tables
for link in races.url:
    print(link)
    try:
        # print("try 0")
        df = pd.read_html(link)[0]
        if 'Weather' in list(df.iloc[:,0]):
            n = list(df.iloc[:,0]).index('Weather')
            info.append(df.iloc[n,1])
        else:
            # print("not in 0, look at 1")
            df = pd.read_html(link)[1]
            if 'Weather' in list(df.iloc[:,0]):
                n = list(df.iloc[:,0]).index('Weather')
                info.append(df.iloc[n,1])
            else:
                # print("not in 1, look at 2")
                df = pd.read_html(link)[2]
                if 'Weather' in list(df.iloc[:,0]):
                    n = list(df.iloc[:,0]).index('Weather')
                    info.append(df.iloc[n,1])
                else:
                    # print("not in 2, look at 3")
                    df = pd.read_html(link)[3]
                    if 'Weather' in list(df.iloc[:,0]):
                        n = list(df.iloc[:,0]).index('Weather')
                        info.append(df.iloc[n,1])
                    else:
                        # print("not in 3, look at Italian version")
                        # Get Italiano page
                        r = requests.get(link)
                        soup = BeautifulSoup(r.content, 'html.parser')
                        driver_names = []
                        class_name = "interlanguage-link-target"
                        for page in soup.find_all('a', attrs = {'class':class_name}):
                            if page.get('lang') == "it":
                                link_it = page.get('href')
                        # Get weather in Italiano
                        r = requests.get(link_it)
                        soup = BeautifulSoup(r.content, 'html.parser')
                        table = soup.find('table', class_="sinottico")
                        for row in soup.find_all('tr'):
                            if any('Clima' in th.get_text() for th in row.find_all('th')):
                                clima = row.find('td')
                                if clima:
                                    info.append(clima.get_text().strip())
                            else:
                                info.append("not found")
                                break
                                
        print(len(info))
    except:
        print("failed")
        info.append("not found")
# append column with weather information to dataframe  
weather['weather'] = info

# set up a dictionary to convert weather information into keywords
weather_dict = {'weather_warm': ['soleggiato', 'clear', 'warm', 'hot', 'sunny', 'fine', 'mild', 'sereno', 'sunny,'],
               'weather_cold': ['cold', 'fresh', 'chilly', 'cool'],
               'weather_dry': ['dry', 'asciutto'],
               'weather_wet': ['showers', 'wet', 'rain', 'pioggia', 'damp', 'thunderstorms', 'rainy'],
               'weather_cloudy': ['overcast', 'nuvoloso', 'clouds', 'cloudy', 'grey', 'coperto']}

# map new df according to weather dictionary
weather_df = pd.DataFrame(columns = weather_dict.keys())
for col in weather_df:
    weather_df[col] = weather['weather'].map(lambda x: 1 if any(i in weather_dict[col] for i in x.lower().split()) else 0)
weather_info = pd.concat([weather, weather_df], axis = 1)

weather.to_csv("./data/weather.csv", sep=',', index=False)
weather_info.to_csv("./data/weather_info.csv", sep=',', index=False)
# display(weather_info)
# Out:
# 185
# http://en.wikipedia.org/wiki/2015_Australian_Grand_Prix
# 1
# http://en.wikipedia.org/wiki/2015_Malaysian_Grand_Prix
# 2
# http://en.wikipedia.org/wiki/2015_Chinese_Grand_Prix
# 3
# http://en.wikipedia.org/wiki/2015_Bahrain_Grand_Prix
# 4
# http://en.wikipedia.org/wiki/2015_Spanish_Grand_Prix
# 5
# http://en.wikipedia.org/wiki/2015_Monaco_Grand_Prix
# 6
# http://en.wikipedia.org/wiki/2015_Canadian_Grand_Prix
# 7
# http://en.wikipedia.org/wiki/2015_Austrian_Grand_Prix
# 8
# http://en.wikipedia.org/wiki/2015_British_Grand_Prix
# 9
# http://en.wikipedia.org/wiki/2015_Hungarian_Grand_Prix
# 10
# http://en.wikipedia.org/wiki/2015_Belgian_Grand_Prix
# 11
# http://en.wikipedia.org/wiki/2015_Italian_Grand_Prix
# 12
# http://en.wikipedia.org/wiki/2015_Singapore_Grand_Prix
# 13
# http://en.wikipedia.org/wiki/2015_Japanese_Grand_Prix
# 14
# http://en.wikipedia.org/wiki/2015_Russian_Grand_Prix
# 15
# http://en.wikipedia.org/wiki/2015_United_States_Grand_Prix
# 16
# http://en.wikipedia.org/wiki/2015_Mexican_Grand_Prix
# 17
# http://en.wikipedia.org/wiki/2015_Brazilian_Grand_Prix
# 18
# http://en.wikipedia.org/wiki/2015_Abu_Dhabi_Grand_Prix
# 19
# http://en.wikipedia.org/wiki/2016_Australian_Grand_Prix
# 20
# http://en.wikipedia.org/wiki/2016_Bahrain_Grand_Prix
# 21
# http://en.wikipedia.org/wiki/2016_Chinese_Grand_Prix
# 22
# http://en.wikipedia.org/wiki/2016_Russian_Grand_Prix
# 23
# http://en.wikipedia.org/wiki/2016_Spanish_Grand_Prix
# 24
# http://en.wikipedia.org/wiki/2016_Monaco_Grand_Prix
# 25
# http://en.wikipedia.org/wiki/2016_Canadian_Grand_Prix
# 26
# http://en.wikipedia.org/wiki/2016_European_Grand_Prix
# 27
# http://en.wikipedia.org/wiki/2016_Austrian_Grand_Prix
# 28
# http://en.wikipedia.org/wiki/2016_British_Grand_Prix
# 29
# http://en.wikipedia.org/wiki/2016_Hungarian_Grand_Prix
# 30
# http://en.wikipedia.org/wiki/2016_German_Grand_Prix
# 31
# http://en.wikipedia.org/wiki/2016_Belgian_Grand_Prix
# 32
# http://en.wikipedia.org/wiki/2016_Italian_Grand_Prix
# 33
# http://en.wikipedia.org/wiki/2016_Singapore_Grand_Prix
# 34
# http://en.wikipedia.org/wiki/2016_Malaysian_Grand_Prix
# 35
# http://en.wikipedia.org/wiki/2016_Japanese_Grand_Prix
# 36
# http://en.wikipedia.org/wiki/2016_United_States_Grand_Prix
# 37
# http://en.wikipedia.org/wiki/2016_Mexican_Grand_Prix
# 38
# http://en.wikipedia.org/wiki/2016_Brazilian_Grand_Prix
# 39
# http://en.wikipedia.org/wiki/2016_Abu_Dhabi_Grand_Prix
# 40
# http://en.wikipedia.org/wiki/2017_Australian_Grand_Prix
# 41
# http://en.wikipedia.org/wiki/2017_Chinese_Grand_Prix
# 42
# http://en.wikipedia.org/wiki/2017_Bahrain_Grand_Prix
# 43
# http://en.wikipedia.org/wiki/2017_Russian_Grand_Prix
# 44
# http://en.wikipedia.org/wiki/2017_Spanish_Grand_Prix
# 45
# http://en.wikipedia.org/wiki/2017_Monaco_Grand_Prix
# 46
# http://en.wikipedia.org/wiki/2017_Canadian_Grand_Prix
# 47
# http://en.wikipedia.org/wiki/2017_Azerbaijan_Grand_Prix
# 48
# http://en.wikipedia.org/wiki/2017_Austrian_Grand_Prix
# 49
# http://en.wikipedia.org/wiki/2017_British_Grand_Prix
# 50
# http://en.wikipedia.org/wiki/2017_Hungarian_Grand_Prix
# 51
# http://en.wikipedia.org/wiki/2017_Belgian_Grand_Prix
# 52
# http://en.wikipedia.org/wiki/2017_Italian_Grand_Prix
# 53
# http://en.wikipedia.org/wiki/2017_Singapore_Grand_Prix
# 54
# http://en.wikipedia.org/wiki/2017_Malaysian_Grand_Prix
# 55
# http://en.wikipedia.org/wiki/2017_Japanese_Grand_Prix
# 56
# http://en.wikipedia.org/wiki/2017_United_States_Grand_Prix
# 57
# http://en.wikipedia.org/wiki/2017_Mexican_Grand_Prix
# 58
# http://en.wikipedia.org/wiki/2017_Brazilian_Grand_Prix
# 59
# http://en.wikipedia.org/wiki/2017_Abu_Dhabi_Grand_Prix
# 60
# http://en.wikipedia.org/wiki/2018_Australian_Grand_Prix
# 61
# http://en.wikipedia.org/wiki/2018_Bahrain_Grand_Prix
# 62
# http://en.wikipedia.org/wiki/2018_Chinese_Grand_Prix
# 63
# http://en.wikipedia.org/wiki/2018_Azerbaijan_Grand_Prix
# 64
# http://en.wikipedia.org/wiki/2018_Spanish_Grand_Prix
# 65
# http://en.wikipedia.org/wiki/2018_Monaco_Grand_Prix
# 66
# http://en.wikipedia.org/wiki/2018_Canadian_Grand_Prix
# 67
# http://en.wikipedia.org/wiki/2018_French_Grand_Prix
# 68
# http://en.wikipedia.org/wiki/2018_Austrian_Grand_Prix
# 69
# http://en.wikipedia.org/wiki/2018_British_Grand_Prix
# 70
# http://en.wikipedia.org/wiki/2018_German_Grand_Prix
# 71
# http://en.wikipedia.org/wiki/2018_Hungarian_Grand_Prix
# 72
# http://en.wikipedia.org/wiki/2018_Belgian_Grand_Prix
# 73
# http://en.wikipedia.org/wiki/2018_Italian_Grand_Prix
# 74
# http://en.wikipedia.org/wiki/2018_Singapore_Grand_Prix
# 75
# http://en.wikipedia.org/wiki/2018_Russian_Grand_Prix
# 76
# http://en.wikipedia.org/wiki/2018_Japanese_Grand_Prix
# 77
# http://en.wikipedia.org/wiki/2018_United_States_Grand_Prix
# 78
# http://en.wikipedia.org/wiki/2018_Mexican_Grand_Prix
# 79
# http://en.wikipedia.org/wiki/2018_Brazilian_Grand_Prix
# 80
# http://en.wikipedia.org/wiki/2018_Abu_Dhabi_Grand_Prix
# 81
# http://en.wikipedia.org/wiki/2019_Australian_Grand_Prix
# 82
# http://en.wikipedia.org/wiki/2019_Bahrain_Grand_Prix
# 83
# http://en.wikipedia.org/wiki/2019_Chinese_Grand_Prix
# 84
# http://en.wikipedia.org/wiki/2019_Azerbaijan_Grand_Prix
# 85
# http://en.wikipedia.org/wiki/2019_Spanish_Grand_Prix
# 86
# http://en.wikipedia.org/wiki/2019_Monaco_Grand_Prix
# 87
# http://en.wikipedia.org/wiki/2019_Canadian_Grand_Prix
# 88
# http://en.wikipedia.org/wiki/2019_French_Grand_Prix
# 89
# http://en.wikipedia.org/wiki/2019_Austrian_Grand_Prix
# 90
# http://en.wikipedia.org/wiki/2019_British_Grand_Prix
# 91
# http://en.wikipedia.org/wiki/2019_German_Grand_Prix
# 92
# http://en.wikipedia.org/wiki/2019_Hungarian_Grand_Prix
# 93
# http://en.wikipedia.org/wiki/2019_Belgian_Grand_Prix
# 94
# http://en.wikipedia.org/wiki/2019_Italian_Grand_Prix
# 95
# http://en.wikipedia.org/wiki/2019_Singapore_Grand_Prix
# 96
# http://en.wikipedia.org/wiki/2019_Russian_Grand_Prix
# 97
# http://en.wikipedia.org/wiki/2019_Japanese_Grand_Prix
# 98
# http://en.wikipedia.org/wiki/2019_Mexican_Grand_Prix
# 99
# http://en.wikipedia.org/wiki/2019_United_States_Grand_Prix
# 100
# http://en.wikipedia.org/wiki/2019_Brazilian_Grand_Prix
# 101
# http://en.wikipedia.org/wiki/2019_Abu_Dhabi_Grand_Prix
# 102
# http://en.wikipedia.org/wiki/2020_Austrian_Grand_Prix
# 103
# http://en.wikipedia.org/wiki/2020_Styrian_Grand_Prix
# 104
# http://en.wikipedia.org/wiki/2020_Hungarian_Grand_Prix
# 105
# http://en.wikipedia.org/wiki/2020_British_Grand_Prix
# 106
# http://en.wikipedia.org/wiki/70th_Anniversary_Grand_Prix
# 107
# http://en.wikipedia.org/wiki/2020_Spanish_Grand_Prix
# 108
# http://en.wikipedia.org/wiki/2020_Belgian_Grand_Prix
# 109
# http://en.wikipedia.org/wiki/2020_Italian_Grand_Prix
# 110
# http://en.wikipedia.org/wiki/2020_Tuscan_Grand_Prix
# 111
# http://en.wikipedia.org/wiki/2020_Russian_Grand_Prix
# 112
# http://en.wikipedia.org/wiki/2020_Eifel_Grand_Prix
# 113
# http://en.wikipedia.org/wiki/2020_Portuguese_Grand_Prix
# 114
# http://en.wikipedia.org/wiki/2020_Emilia_Romagna_Grand_Prix
# 115
# http://en.wikipedia.org/wiki/2020_Turkish_Grand_Prix
# 116
# http://en.wikipedia.org/wiki/2020_Bahrain_Grand_Prix
# 117
# http://en.wikipedia.org/wiki/2020_Sakhir_Grand_Prix
# 118
# http://en.wikipedia.org/wiki/2020_Abu_Dhabi_Grand_Prix
# 119
# http://en.wikipedia.org/wiki/2021_Bahrain_Grand_Prix
# 120
# http://en.wikipedia.org/wiki/2021_Emilia_Romagna_Grand_Prix
# 121
# http://en.wikipedia.org/wiki/2021_Portuguese_Grand_Prix
# 122
# http://en.wikipedia.org/wiki/2021_Spanish_Grand_Prix
# 123
# http://en.wikipedia.org/wiki/2021_Monaco_Grand_Prix
# 124
# http://en.wikipedia.org/wiki/2021_Azerbaijan_Grand_Prix
# 125
# http://en.wikipedia.org/wiki/2021_French_Grand_Prix
# 126
# http://en.wikipedia.org/wiki/2021_Styrian_Grand_Prix
# 127
# http://en.wikipedia.org/wiki/2021_Austrian_Grand_Prix
# 128
# http://en.wikipedia.org/wiki/2021_British_Grand_Prix
# 129
# http://en.wikipedia.org/wiki/2021_Hungarian_Grand_Prix
# 130
# http://en.wikipedia.org/wiki/2021_Belgian_Grand_Prix
# 131
# http://en.wikipedia.org/wiki/2021_Dutch_Grand_Prix
# 132
# http://en.wikipedia.org/wiki/2021_Italian_Grand_Prix
# 133
# http://en.wikipedia.org/wiki/2021_Russian_Grand_Prix
# 134
# http://en.wikipedia.org/wiki/2021_Turkish_Grand_Prix
# 135
# http://en.wikipedia.org/wiki/2021_United_States_Grand_Prix
# 136
# http://en.wikipedia.org/wiki/2021_Mexican_Grand_Prix
# 137
# http://en.wikipedia.org/wiki/2021_S%C3%A3o_Paulo_Grand_Prix
# 138
# http://en.wikipedia.org/wiki/2021_Qatar_Grand_Prix
# 139
# http://en.wikipedia.org/wiki/2021_Saudi_Arabian_Grand_Prix
# 140
# http://en.wikipedia.org/wiki/2021_Abu_Dhabi_Grand_Prix
# 141
# http://en.wikipedia.org/wiki/2022_Bahrain_Grand_Prix
# 142
# http://en.wikipedia.org/wiki/2022_Saudi_Arabian_Grand_Prix
# 143
# http://en.wikipedia.org/wiki/2022_Australian_Grand_Prix
# 144
# http://en.wikipedia.org/wiki/2022_Emilia_Romagna_Grand_Prix
# 145
# http://en.wikipedia.org/wiki/2022_Miami_Grand_Prix
# 146
# http://en.wikipedia.org/wiki/2022_Spanish_Grand_Prix
# 147
# http://en.wikipedia.org/wiki/2022_Monaco_Grand_Prix
# 148
# http://en.wikipedia.org/wiki/2022_Azerbaijan_Grand_Prix
# 149
# http://en.wikipedia.org/wiki/2022_Canadian_Grand_Prix
# 150
# http://en.wikipedia.org/wiki/2022_British_Grand_Prix
# 151
# http://en.wikipedia.org/wiki/2022_Austrian_Grand_Prix
# 152
# http://en.wikipedia.org/wiki/2022_French_Grand_Prix
# 153
# http://en.wikipedia.org/wiki/2022_Hungarian_Grand_Prix
# 154
# http://en.wikipedia.org/wiki/2022_Belgian_Grand_Prix
# 155
# http://en.wikipedia.org/wiki/2022_Dutch_Grand_Prix
# 156
# http://en.wikipedia.org/wiki/2022_Italian_Grand_Prix
# 157
# http://en.wikipedia.org/wiki/2022_Singapore_Grand_Prix
# 158
# http://en.wikipedia.org/wiki/2022_Japanese_Grand_Prix
# 159
# http://en.wikipedia.org/wiki/2022_United_States_Grand_Prix
# 160
# http://en.wikipedia.org/wiki/2022_Mexican_Grand_Prix
# 161
# http://en.wikipedia.org/wiki/2022_Brazilian_Grand_Prix
# 162
# http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Grand_Prix
# 163
# https://en.wikipedia.org/wiki/2023_Bahrain_Grand_Prix
# 164
# https://en.wikipedia.org/wiki/2023_Saudi_Arabian_Grand_Prix
# 165
# https://en.wikipedia.org/wiki/2023_Australian_Grand_Prix
# 166
# https://en.wikipedia.org/wiki/2023_Azerbaijan_Grand_Prix
# 167
# https://en.wikipedia.org/wiki/2023_Miami_Grand_Prix
# 168
# https://en.wikipedia.org/wiki/2023_Monaco_Grand_Prix
# 169
# https://en.wikipedia.org/wiki/2023_Spanish_Grand_Prix
# 170
# https://en.wikipedia.org/wiki/2023_Canadian_Grand_Prix
# 171
# https://en.wikipedia.org/wiki/2023_Austrian_Grand_Prix
# 172
# https://en.wikipedia.org/wiki/2023_British_Grand_Prix
# 173
# https://en.wikipedia.org/wiki/2023_Hungarian_Grand_Prix
# 174
# https://en.wikipedia.org/wiki/2023_Belgian_Grand_Prix
# 175
# https://en.wikipedia.org/wiki/2023_Dutch_Grand_Prix
# 176
# https://en.wikipedia.org/wiki/2023_Italian_Grand_Prix
# 177
# https://en.wikipedia.org/wiki/2023_Singapore_Grand_Prix
# 178
# https://en.wikipedia.org/wiki/2023_Japanese_Grand_Prix
# 179
# https://en.wikipedia.org/wiki/2023_Qatar_Grand_Prix
# 180
# https://en.wikipedia.org/wiki/2023_United_States_Grand_Prix
# 181
# https://en.wikipedia.org/wiki/2023_Mexico_City_Grand_Prix
# 182
# https://en.wikipedia.org/wiki/2023_S%C3%A3o_Paulo_Grand_Prix
# 183
# https://en.wikipedia.org/wiki/2023_Las_Vegas_Grand_Prix
# 184
# https://en.wikipedia.org/wiki/2023_Abu_Dhabi_Grand_Prix
# 185
# /var/folders/st/9_21pbsj10q04h62rltd9x980000gn/T/ipykernel_27565/984341844.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather['weather'] = info

# %%
# ===================================
# Get Event Links from Motorsport.com
# ===================================
# import requests
# from bs4 import BeautifulSoup
# all_event_links_df = pd.DataFrame()
# for year in range(FROM_YEAR, THIS_YEAR):
#     url = f"https://www.autosport.com/f1/results/{year}"
#     r = requests.get(url)
#     soup = BeautifulSoup(r.text, 'html.parser')
#     event_links = []
#     class_name = "ms-select__option ms-select__option--event"
#     for page in soup.find_all('a', attrs = {'class':class_name}):
#         link = page.get('href')
#         # print(link)
#         elink = url.replace(f"/f1/results/{year}", link)
#         # print(url)
#         event_links.append(elink)
#     print(len(event_links))
#     rounds = [x for x in range(1, len(event_links)+1)]
#     event_links_df = pd.DataFrame({
#         "season": year,
#         "round": rounds,
#         "event_link": event_links
#     })
#     # display(event_links_df)
#     all_event_links_df = pd.concat([all_event_links_df, event_links_df], axis=0).reset_index(drop=True)
#     all_event_links_df = all_event_links_df.iloc[:len(all_event_links_df)-1]
# display(all_event_links_df)
# all_event_links_df.to_csv("./data/autosport_links_error.csv", index=False)

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
from datetime import timedelta
import requests

def time_cleanup(input_string):
    result_string = np.nan
    try:
        groups = input_string.split(" ")
        if len(groups) == 1:
            result_string = groups[0]
        if len(groups) == 2:
            result_string = groups[1]
        if len(groups) == 3:
            result_string = groups[2]
    except:
        print("time cleanup error")
    return result_string

def convert_time(time_str):
    rounded = np.nan
    try:
        # print(time_str)
        # Splitting the time into minutes and seconds

        # minutes, seconds = time_str.split("'")
        time_strings = time_str.split("'")
        if len(time_strings) == 1:
            hours = 0
            minutes = 0
            seconds = time_strings[0]
        elif len(time_strings) == 2:
            hours = 0
            minutes = time_strings[0]
            seconds = time_strings[1]
        elif len(time_strings) == 3:
            hours = time_strings[0]
            minutes = time_strings[1]
            seconds = time_strings[2]

        total_seconds = int(hours) * 60 * 60 + int(minutes) * 60 + float(seconds)
        # Converting total seconds to hh:mm:ss format
        formatted_time = timedelta(seconds=total_seconds)
        # Formatting the output to round milliseconds to 3 decimal places
        rounded = '{:02}:{:02}:{:06.3f}'.format(int(formatted_time.total_seconds() // 3600),
                                            int(formatted_time.total_seconds() % 3600 // 60),
                                            formatted_time.total_seconds() % 60)
        # print(rounded)
    except:
        print("time convert error")
    # print(rounded)
    return rounded

def time_to_milliseconds(time_str):
    milliseconds = np.nan
    try:
        parts = time_str.split(':')
        milliseconds = 0

        if len(parts) == 3:
            # Format is hours:minutes:seconds.milliseconds
            hours, minutes, seconds = parts
            milliseconds += int(hours) * 3600000  # Convert hours to milliseconds
            milliseconds += int(minutes) * 60000  # Convert minutes to milliseconds
        elif len(parts) == 2:
            # Format is minutes:seconds.milliseconds
            minutes, seconds = parts
            milliseconds += int(minutes) * 60000  # Convert minutes to milliseconds
        else:
            raise ValueError("Invalid time format")

        # Splitting seconds and milliseconds and converting
        seconds, msec = seconds.split('.')
        milliseconds += int(seconds) * 1000  # Convert seconds to milliseconds
        milliseconds += int(msec)  # Add milliseconds
    except:
        print("time to milli error")
    return milliseconds

def remove_space(input):
    result = str(input)
    result = result.replace(" ", "")
    return result

def to_int(input):
    result = np.nan
    try:
        result = int(input)
    except:
        print("error when casting to int")
    return result

def get_tyre_type(input):
    return input.split(":")[0]

all_event_links_df = pd.read_csv("./data/autosport_links.csv")

# TODO: Comment after testing completed
# condition = (all_event_links_df['season'] == 2021) & (all_event_links_df['round'] == 10)
# all_event_links_df = all_event_links_df[condition]

all_races = pd.DataFrame()
for row in all_event_links_df.itertuples():
    url = all_event_links_df.at[row.Index, 'event_link']
    season = all_event_links_df.at[row.Index, 'season']
    round = all_event_links_df.at[row.Index, 'round']
    print(f"season: {season}, round: {round}")
    race = pd.DataFrame()

    # ==============
    # Free Practices
    # ==============
    for i in range(1,4):
        try:
            fp_url = f"{url}?st=FP{i}"
            print(fp_url)
            # Get driver names
            r = requests.get(fp_url)
            soup = BeautifulSoup(r.text, 'html.parser')
            driver_names = []
            class_name = "ms-link info-wrapper"
            for page in soup.find_all('a', attrs = {'class':class_name}):
                link = page.get('href')
                name = link.split("/")[2]
                name = name.replace("-", " ")
                name = name.lower()
                driver_names.append(name)
            name_df = pd.DataFrame({"driver_name": driver_names})
            table_df = pd.DataFrame()
            try: 
                table_df = pd.read_html(fp_url)
            except:
                print("no data")
                continue
            table_df = table_df[0]
            table_df.columns = table_df.columns.droplevel(0)
            table_df = table_df[['Cla', 'Time']]
            # display(table_df)
            table_df['Cla'] = table_df['Cla'].apply(to_int)
            table_df['Time'] = table_df['Time'].apply(time_cleanup)
            table_df['Time'] = table_df['Time'].apply(convert_time)
            table_df['Time'] = table_df['Time'].apply(time_to_milliseconds)
            table_df.rename(columns = {'Cla': f"fp_pos_{i}", 'Time': f"fp_time_{i}"}, inplace = True)
            df = pd.concat([name_df, table_df], axis=1)
            df['season'] = season
            df['round'] = round
            # df['fp_url'] = fp_url
            # display(df)
            if race.empty:
                race = df
            else:
                race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
        except:
            print("no data")
            
    # ==============
    # Fastest Lap
    # ==============
    try:
        fl_url = f"{url}?st=FL"
        print(fl_url)
        # Get driver names
        r = requests.get(fl_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"
        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})
        table_df = pd.DataFrame()
        try: 
            table_df = pd.read_html(fl_url)
        except:
            print("no data")
            # continue
        table_df = table_df[0]
        table_df.columns = table_df.columns.droplevel(0)
        table_df = table_df[['Cla', 'Time']]
        table_df['Cla'] = table_df['Cla'].apply(to_int)
        table_df['Time'] = table_df['Time'].apply(time_cleanup)
        table_df['Time'] = table_df['Time'].apply(convert_time)
        table_df['Time'] = table_df['Time'].apply(time_to_milliseconds)
        table_df.rename(columns = {'Cla': f"fl_pos", 'Time': f"fl_time"}, inplace = True)
        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        # df['fl_url'] = fl_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data under tag FL, try FL2")
        try:
            fl2_url = f"{url}?st=FL2"
            print(fl2_url)
            # Get driver names
            r = requests.get(fl2_url)
            soup = BeautifulSoup(r.text, 'html.parser')
            driver_names = []
            class_name = "ms-link info-wrapper"
            for page in soup.find_all('a', attrs = {'class':class_name}):
                link = page.get('href')
                name = link.split("/")[2]
                name = name.replace("-", " ")
                name = name.lower()
                driver_names.append(name)
            name_df = pd.DataFrame({"driver_name": driver_names})
            table_df = pd.DataFrame()
            try: 
                table_df = pd.read_html(fl2_url)
            except:
                print("no data")
                # continue
            table_df = table_df[0]
            table_df.columns = table_df.columns.droplevel(0)
            table_df = table_df[['Cla', 'Time']]
            table_df['Cla'] = table_df['Cla'].apply(to_int)
            table_df['Time'] = table_df['Time'].apply(time_cleanup)
            table_df['Time'] = table_df['Time'].apply(convert_time)
            table_df['Time'] = table_df['Time'].apply(time_to_milliseconds)
            table_df.rename(columns = {'Cla': f"fl_pos", 'Time': f"fl_time"}, inplace = True)
            df = pd.concat([name_df, table_df], axis=1)
            df['season'] = season
            df['round'] = round
            # df['fl_url'] = fl_url
            # display(df)
            if race.empty:
                race = df
            else:
                race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
        except:
            print("no data")

    # ==============
    # Initial Tyre
    # ==============
    try:
        th_url = f"{url}?st=TH"
        print(th_url)
        # Get driver names
        r = requests.get(th_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"
        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})
        table_df = pd.DataFrame()
        try: 
            table_df = pd.read_html(th_url)
        except:
            print("no data")
            # continue
        table_df = table_df[0]
        table_df.columns = table_df.columns.droplevel(0)
        table_df = table_df[['1']]
        table_df['1'] = table_df['1'].apply(remove_space)
        table_df['1'] = table_df['1'].apply(get_tyre_type)
        table_df.rename(columns = {'1': f"initial_tyre"}, inplace = True)
        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        # df['th_url'] = th_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data")

    # ==============
    # Pit Stops
    # ==============
    try:
        ps_url = f"{url}?st=RACE"
        print(ps_url)
        # Get driver names
        r = requests.get(ps_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"
        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})
        name_df = name_df.drop_duplicates(subset='driver_name', keep='first')
        # display(name_df['driver_name'])
        table_df = pd.DataFrame()
        try: 
            table_df = pd.read_html(ps_url)
        except:
            print("no data")
            # continue
        table_df = table_df[0]
        # display(table_df)
        table_df.columns = table_df.columns.droplevel(0)
        table_df = table_df[['Pits']]
        # table_df['Pits'] = table_df['Pits'].apply(remove_space)
        # table_df['Pits'] = table_df['Pits'].apply(get_tyre_type)
        table_df.rename(columns = {'Pits': f"num_o_ps"}, inplace = True)
        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        # df['ps_url'] = ps_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data")

    # ==============
    # Qualifying Position/Time
    # ==============
    try:
        qp_url = f"{url}?st=GRID"
        print(qp_url)
        # Get driver names
        r = requests.get(qp_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"
        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})
        table_df = pd.DataFrame()
        try: 
            table_df = pd.read_html(qp_url)
            table_df = table_df[0]
            table_df.columns = table_df.columns.droplevel(0)
            table_df = table_df[['Cla', 'Time']]
            table_df['Cla'] = table_df['Cla'].apply(to_int)
            table_df['Time'] = table_df['Time'].apply(time_cleanup)
            table_df['Time'] = table_df['Time'].apply(convert_time)
            table_df['Time'] = table_df['Time'].apply(time_to_milliseconds)
        except:
            print("no data found under tab GRID, try GRID1 for time and GRID2 for position")
            try:
                qp_time_url = f"{url}?st=GRID1"
                table_time_df = pd.read_html(qp_time_url)
                table_time_df = table_time_df[0]
                table_time_df.columns = table_time_df.columns.droplevel(0)
                table_time_df = table_time_df[['Time']]
                table_time_df['Time'] = table_time_df['Time'].apply(time_cleanup)
                table_time_df['Time'] = table_time_df['Time'].apply(convert_time)
                table_time_df['Time'] = table_time_df['Time'].apply(time_to_milliseconds)

            except:
                print("no Time data found under tab GRID1")

            try:
                qp_position_url = f"{url}?st=GRID2"
                table_pos_df = pd.read_html(qp_position_url)
                table_pos_df = table_pos_df[0]
                table_pos_df.columns = table_pos_df.columns.droplevel(0)
                table_pos_df = table_pos_df[['Cla']]
                table_pos_df['Cla'] = table_pos_df['Cla'].apply(to_int)
            except:
                print("no Position data found under tab GRID2")

            table_df = pd.concat([table_pos_df, table_time_df], axis=1)
            # continue
        
        table_df.rename(columns = {'Cla': "qualifying_position", 'Time':"qualifying_time"}, inplace = True)
        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        # display(table_df)
        # df['qp_url'] = qp_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data")


    hasSprint = False
    # ==============
    # Sprint Position / Time
    # ==============
    try: 
        spr_url = f"{url}?st=SPR"
        print(spr_url)
        # Get driver names
        r = requests.get(spr_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"
        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})    
        # display(name_df)
        hasSprint = True
        r = requests.get(spr_url)
        soup = BeautifulSoup(r.content, 'html.parser')
        table = soup.find('table')
        data = []
        for row in table.find_all('tr'):
            cols = row.find_all('td')
            if len(cols) > 1:  # Adjust this index based on the position of Cal and Time columns
                cla_data = cols[0].text.strip()
                laps_data = cols[4].text.strip()
                time_data = cols[5].text.strip().replace("                        \n\n                                ", " ")
                data.append((cla_data, laps_data, time_data))
        # print(data)
        table_df = pd.DataFrame(data, columns=['sprint_position', 'sprint_laps', 'sprint_time'])
        table_df['sprint_time'] = table_df['sprint_time'].apply(time_cleanup)
        table_df['sprint_time'] = table_df['sprint_time'].apply(convert_time)
        table_df['sprint_time'] = table_df['sprint_time'].apply(time_to_milliseconds)
        # display(table_df)
        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        df['has_sprint'] = True
        # df['spr_grid_url'] = spr_grid_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data found under tag SPR, try QR")
        try: 
            spr_es_url = f"{url}?st=QR"
            print(spr_es_url)
            # Get driver names
            r = requests.get(spr_es_url)
            soup = BeautifulSoup(r.text, 'html.parser')
            driver_names = []
            class_name = "ms-link info-wrapper"
            for page in soup.find_all('a', attrs = {'class':class_name}):
                link = page.get('href')
                name = link.split("/")[2]
                name = name.replace("-", " ")
                name = name.lower()
                driver_names.append(name)
            name_df = pd.DataFrame({"driver_name": driver_names})    
            # display(name_df)
            hasSprint = True
            r = requests.get(spr_es_url)
            soup = BeautifulSoup(r.content, 'html.parser')
            table = soup.find('table')
            data = []
            for row in table.find_all('tr'):
                cols = row.find_all('td')
                if len(cols) > 1:  # Adjust this index based on the position of Cal and Time columns
                    cla_data = cols[0].text.strip()
                    laps_data = cols[4].text.strip()
                    time_data = cols[5].text.strip().replace("                        \n\n                                ", " ")
                    data.append((cla_data, laps_data, time_data))
            # print(data)
            table_df = pd.DataFrame(data, columns=['sprint_position', 'sprint_laps', 'sprint_time'])
            table_df['sprint_time'] = table_df['sprint_time'].apply(time_cleanup)
            table_df['sprint_time'] = table_df['sprint_time'].apply(convert_time)
            table_df['sprint_time'] = table_df['sprint_time'].apply(time_to_milliseconds)
            # display(table_df)
            df = pd.concat([name_df, table_df], axis=1)
            df['season'] = season
            df['round'] = round
            df['has_sprint'] = True
            # df['spr_grid_url'] = spr_grid_url
            # display(df)
            if race.empty:
                race = df
            else:
                race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
        except:
            print("no data")

    # ==============
    # Qualifying Sprint Position / Time
    # ==============
    try: 
        spr_grid_url = f"{url}?st=SPR+GRID"
        print(spr_grid_url)

        # Get driver names
        r = requests.get(spr_grid_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"

        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})    
        # display(name_df)

        hasSprint = True

        r = requests.get(spr_grid_url)
        soup = BeautifulSoup(r.content, 'html.parser')
        table = soup.find('table')
        data = []
        for row in table.find_all('tr'):
            cols = row.find_all('td')
            if len(cols) > 1:  # Adjust this index based on the position of Cal and Time columns
                cal_data = cols[0].text.strip()
                time_data = cols[6].text.strip().replace("                        \n\n                                ", " ")
                data.append((cal_data, time_data))
        # print(data)
        table_df = pd.DataFrame(data, columns=['qualifying_sprint_position', 'qualifying_sprint_time'])
        table_df['qualifying_sprint_time'] = table_df['qualifying_sprint_time'].apply(time_cleanup)
        table_df['qualifying_sprint_time'] = table_df['qualifying_sprint_time'].apply(convert_time)
        table_df['qualifying_sprint_time'] = table_df['qualifying_sprint_time'].apply(time_to_milliseconds)
        # display(table_df)

        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        # df['spr_grid_url'] = spr_grid_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data found under tad SPR GRID, try GRID1")
        try: 
            grid1_url = f"{url}?st=GRID1"
            print(grid1_url)

            # Get driver names
            r = requests.get(grid1_url)
            soup = BeautifulSoup(r.text, 'html.parser')
            driver_names = []
            class_name = "ms-link info-wrapper"

            for page in soup.find_all('a', attrs = {'class':class_name}):
                link = page.get('href')
                name = link.split("/")[2]
                name = name.replace("-", " ")
                name = name.lower()
                driver_names.append(name)
            name_df = pd.DataFrame({"driver_name": driver_names})    
            # display(name_df)

            hasSprint = True

            r = requests.get(grid1_url)
            soup = BeautifulSoup(r.content, 'html.parser')
            table = soup.find('table')
            data = []
            for row in table.find_all('tr'):
                cols = row.find_all('td')
                if len(cols) > 1:  # Adjust this index based on the position of Cal and Time columns
                    cal_data = cols[0].text.strip()
                    time_data = cols[6].text.strip().replace("                        \n\n                                ", " ")
                    data.append((cal_data, time_data))
            # print(data)
            table_df = pd.DataFrame(data, columns=['qualifying_sprint_position', 'qualifying_sprint_time'])
            table_df['qualifying_sprint_time'] = table_df['qualifying_sprint_time'].apply(time_cleanup)
            table_df['qualifying_sprint_time'] = table_df['qualifying_sprint_time'].apply(convert_time)
            table_df['qualifying_sprint_time'] = table_df['qualifying_sprint_time'].apply(time_to_milliseconds)
            # display(table_df)

            df = pd.concat([name_df, table_df], axis=1)
            df['season'] = season
            df['round'] = round
            # df['spr_grid_url'] = spr_grid_url
            # display(df)
            if race.empty:
                race = df
            else:
                race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
        except:
            print("no data")

    # ==============
    # Sprint Fastest Lap
    # ==============
    try:
        spr_fl_url = f"{url}?st=SPR+FL"
        print(spr_fl_url)
        table_df = pd.read_html(spr_fl_url)
        table_df = table_df[0]
        table_df.columns = table_df.columns.droplevel(0)
        table_df = table_df[['Cla', 'Time']]
        table_df['Cla'] = table_df['Cla'].apply(to_int)
        table_df['Time'] = table_df['Time'].apply(time_cleanup)
        table_df['Time'] = table_df['Time'].apply(convert_time)
        table_df['Time'] = table_df['Time'].apply(time_to_milliseconds)
        table_df.rename(columns = {'Cla': f"sprint_fl_pos", "Time": "sprint_fl_time"}, inplace = True)

        # Get driver names
        r = requests.get(spr_fl_url)
        soup = BeautifulSoup(r.text, 'html.parser')
        driver_names = []
        class_name = "ms-link info-wrapper"
        for page in soup.find_all('a', attrs = {'class':class_name}):
            link = page.get('href')
            name = link.split("/")[2]
            name = name.replace("-", " ")
            name = name.lower()
            driver_names.append(name)
        name_df = pd.DataFrame({"driver_name": driver_names})

        df = pd.concat([name_df, table_df], axis=1)
        df['season'] = season
        df['round'] = round
        # df['spr_fl_url'] = spr_fl_url
        # display(df)
        if race.empty:
            race = df
        else:
            race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
    except:
        print("no data uner tag SPR FL, try FL1")
        try:
            spr_fl1_url = f"{url}?st=FL1"
            print(spr_fl1_url)
            table_df = pd.read_html(spr_fl1_url)
            table_df = table_df[0]
            table_df.columns = table_df.columns.droplevel(0)
            table_df = table_df[['Cla', 'Time']]
            table_df['Cla'] = table_df['Cla'].apply(to_int)
            table_df['Time'] = table_df['Time'].apply(time_cleanup)
            table_df['Time'] = table_df['Time'].apply(convert_time)
            table_df['Time'] = table_df['Time'].apply(time_to_milliseconds)
            table_df.rename(columns = {'Cla': f"sprint_fl_pos", "Time": "sprint_fl_time"}, inplace = True)

            # Get driver names
            r = requests.get(spr_fl1_url)
            soup = BeautifulSoup(r.text, 'html.parser')
            driver_names = []
            class_name = "ms-link info-wrapper"
            for page in soup.find_all('a', attrs = {'class':class_name}):
                link = page.get('href')
                name = link.split("/")[2]
                name = name.replace("-", " ")
                name = name.lower()
                driver_names.append(name)
            name_df = pd.DataFrame({"driver_name": driver_names})

            df = pd.concat([name_df, table_df], axis=1)
            df['season'] = season
            df['round'] = round
            # df['spr_fl_url'] = spr_fl_url
            # display(df)
            if race.empty:
                race = df
            else:
                race = pd.merge(race, df, how='outer', on=['season', 'round', 'driver_name'])
        except:
            print("no data")

    # display(df)
    # display(race)
    print("========================================================================")

    all_races = pd.concat([all_races, race], axis=0).reset_index(drop=True)

all_races.to_csv("./data/autosport.csv", index=False)
# display(all_races)
# Out:
# season: 2015, round: 1
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=FP1
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=FP2
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=FP3
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=FL
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=TH
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=RACE
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=GRID
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/australian-gp-489985/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 2
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=FP2
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=FP3
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=FL
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=TH
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=RACE
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=GRID
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/malaysian-gp-489984/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 3
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=FP1
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=FP2
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=FL
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=TH
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=RACE
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=GRID
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/chinese-gp-489983/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 4
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=FP2
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=FP3
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=FL
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=TH
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=RACE
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=GRID
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/bahrain-gp-489982/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 5
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=FL
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=TH
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=GRID
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/spanish-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 6
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=FL
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=TH
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=GRID
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/monaco-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 7
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=FL
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=TH
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/canadian-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 8
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=FL
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=TH
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/austrian-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 9
# https://www.autosport.com/f1/results/2015/british-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/british-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/british-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/british-gp/?st=FL
# https://www.autosport.com/f1/results/2015/british-gp/?st=TH
# https://www.autosport.com/f1/results/2015/british-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/british-gp/?st=GRID
# https://www.autosport.com/f1/results/2015/british-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/british-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/british-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/british-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/british-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/british-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 10
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=FL
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=TH
# no data
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/hungarian-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 11
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=FL
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=TH
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=GRID
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/belgian-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 12
# https://www.autosport.com/f1/results/2015/italian-gp/?st=FP1
# https://www.autosport.com/f1/results/2015/italian-gp/?st=FP2
# https://www.autosport.com/f1/results/2015/italian-gp/?st=FP3
# https://www.autosport.com/f1/results/2015/italian-gp/?st=FL
# https://www.autosport.com/f1/results/2015/italian-gp/?st=TH
# https://www.autosport.com/f1/results/2015/italian-gp/?st=RACE
# https://www.autosport.com/f1/results/2015/italian-gp/?st=GRID
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2015/italian-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/italian-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/italian-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/italian-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/italian-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/italian-gp/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 13
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=FP1
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=FP2
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=FP3
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=FL
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=TH
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=RACE
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=GRID
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/singapore-gp-488135/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 14
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=FP1
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=FP2
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=FP3
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=FL
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=TH
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=RACE
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=GRID
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/japanese-gp-488134/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 15
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=FP1
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=FP2
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=FP3
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=FL
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=TH
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=RACE
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/russian-gp-488133/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 16
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=FP2
# no data
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=FP3
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=FL
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=TH
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=RACE
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=GRID
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/united-states-gp-488132/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 17
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=FP1
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=FP2
# error when casting to int
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=FP3
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=FL
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=TH
# no data
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=RACE
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/mexican-gp-488111/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 18
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=FP1
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=FP2
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=FP3
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=FL
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=TH
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=RACE
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/brazilian-gp-488131/?st=FL1
# no data
# ========================================================================
# season: 2015, round: 19
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=FP1
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=FP2
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=FL
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=TH
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=RACE
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=QR
# no data
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2015/abu-dhabi-gp-488130/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 1
# https://www.autosport.com/f1/results/2016/australian-gp/?st=FP1
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2016/australian-gp/?st=FP2
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2016/australian-gp/?st=FP3
# https://www.autosport.com/f1/results/2016/australian-gp/?st=FL
# https://www.autosport.com/f1/results/2016/australian-gp/?st=TH
# https://www.autosport.com/f1/results/2016/australian-gp/?st=RACE
# https://www.autosport.com/f1/results/2016/australian-gp/?st=GRID
# https://www.autosport.com/f1/results/2016/australian-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/australian-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/australian-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/australian-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/australian-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/australian-gp/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 2
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=FP1
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=FP2
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=FP3
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=FL
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=TH
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=RACE
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=GRID
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/bahrain-gp-488128/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 3
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=FP1
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=FP2
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=FP3
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=FL
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=TH
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=RACE
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=GRID
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/chinese-gp-488127/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 4
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=FP1
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=FP2
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=FP3
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=FL
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=TH
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=RACE
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/russian-gp-488126/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 5
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=FP2
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=FP3
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=FL
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=TH
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=RACE
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=GRID
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/spanish-gp-488125/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 6
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=FP1
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=FP2
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=FP3
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=FL
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=TH
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=RACE
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=GRID
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/monaco-gp-488124/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 7
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=FP1
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=FP2
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=FP3
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=FL
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=TH
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=RACE
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/canadian-gp-488123/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 8
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=FP1
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=FP2
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=FL
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=TH
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=RACE
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=GRID
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/european-gp-488122/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 9
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=FP1
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=FP2
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=FP3
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=FL
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=TH
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=RACE
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=GRID
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/austrian-gp-488121/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 10
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=FP1
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=FP2
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=FP3
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=FL
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=TH
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=RACE
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=GRID
# error when casting to int
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/british-gp-488120/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 11
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=FP1
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=FP2
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=FP3
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=FL
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=TH
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=RACE
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=GRID
# error when casting to int
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/hungarian-gp-488119/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 12
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=FP1
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=FP2
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=FP3
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=FL
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=TH
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=RACE
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=GRID
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/german-gp-488118/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 13
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=FP2
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=FL
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=TH
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=RACE
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/belgian-gp-488117/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 14
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=FP1
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=FP2
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=FP3
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=FL
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=TH
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=RACE
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/italian-gp-488116/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 15
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=FP2
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=FP3
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=FL
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=TH
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=RACE
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=GRID
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/singapore-gp-488115/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 16
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=FP2
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=FP3
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=FL
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=TH
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=RACE
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=GRID
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/malaysian-gp-488114/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 17
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=FP1
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=FP2
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=FP3
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=FL
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=TH
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=RACE
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=GRID
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/japanese-gp-488113/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 18
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=FP1
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=FP2
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=FP3
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=FL
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=TH
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=RACE
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=GRID
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/united-states-gp-488112/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 19
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=FP1
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=FP2
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=FP3
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=FL
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=TH
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=RACE
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/mexican-gp-488110/?st=FL1
# no data
# ========================================================================
# season: 2016, round: 20
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=FP1
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=FP2
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=FL
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=TH
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=RACE
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=GRID
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=QR
# no data
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2016/brazilian-gp-488109/?st=FL1
# no data
# ...
# https://www.autosport.com/f1/results/2023/canadian-gp-625304/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/canadian-gp-625304/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/canadian-gp-625304/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/canadian-gp-625304/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/canadian-gp-625304/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/canadian-gp-625304/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 9
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=FP1
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=FP2
# no data
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=FP3
# no data
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=FL
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=TH
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=RACE
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=GRID
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=SPR
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=SPR+GRID
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/austrian-gp-625308/?st=SPR+FL
# ========================================================================
# season: 2023, round: 10
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=FP1
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=FP2
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=FL
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=TH
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=RACE
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/british-gp-625312/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 11
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=FP1
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=FP2
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=FP3
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=FL
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=TH
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=RACE
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=GRID
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/hungarian-gp-625316/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 12
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=FP1
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=FP2
# no data
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=FP3
# no data
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=FL
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=TH
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=RACE
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=GRID
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=SPR
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=SPR+GRID
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/belgian-gp-625329/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 13
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=FP2
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=FP3
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=FL
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=TH
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=RACE
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=GRID
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/dutch-gp-625333/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 14
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=FP1
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=FP2
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=FP3
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=FL
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=TH
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=RACE
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=GRID
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/italian-gp-625337/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 15
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=FP1
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=FP2
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=FP3
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=FL
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=TH
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=RACE
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/singapore-gp-625341/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 16
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=FP1
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=FP2
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=FP3
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=FL
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=TH
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=RACE
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/japanese-gp-625345/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 17
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=FP1
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=FP2
# no data
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=FP3
# no data
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=FL
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=TH
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=RACE
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=SPR
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=SPR+GRID
# time convert error
# time convert error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2023/qatar-gp-625349/?st=SPR+FL
# ========================================================================
# season: 2023, round: 18
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=FP1
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=FP2
# no data
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=FP3
# no data
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=FL
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=TH
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=RACE
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=GRID
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=SPR
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=SPR+GRID
# https://www.autosport.com/f1/results/2023/united-states-gp-625353/?st=SPR+FL
# ========================================================================
# season: 2023, round: 19
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=FP1
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=FP2
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=FP3
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=FL
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=TH
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=RACE
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=GRID
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/mexico-city-gp-625357/?st=FL1
# no data
# ========================================================================
# season: 2023, round: 20
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=FP1
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=FP2
# no data
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=FP3
# no data
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=FL
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=TH
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=RACE
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=GRID
# time cleanup error
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=SPR
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=SPR+GRID
# time convert error
# time to milli error
# https://www.autosport.com/f1/results/2023/brazilian-gp-625361/?st=SPR+FL
# ========================================================================
# season: 2023, round: 21
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=FP1
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time cleanup error
# time convert error
# time convert error
# time convert error
# time convert error
# time convert error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# time to milli error
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=FP2
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=FP3
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=FL
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=TH
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=RACE
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=GRID
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=SPR
# no data found under tag SPR, try QR
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=QR
# no data
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=SPR+GRID
# no data found under tad SPR GRID, try GRID1
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=GRID1
# no data
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=SPR+FL
# no data uner tag SPR FL, try FL1
# https://www.autosport.com/f1/results/2023/las-vegas-gp/?st=FL1
# no data
# ========================================================================

# %%
from datetime import datetime
import pytz

results = pd.read_csv("./data/results.csv")
qualifying_results = pd.read_csv("./data/qualifying_results.csv")
weather = pd.read_csv("./data/weather.csv")
weather_info = pd.read_csv("./data/weather_info.csv")
autosport_df = pd.read_csv("./data/autosport.csv")

def strip_z(time):
    # return time.replace("Z", "")
    result = time
    try:
        result = time.replace("Z", "")
    except:
        pass
    return result

def get_local_time(target_city, target_country, time_in_zulu):
    result = np.nan
    try: 
        # Parse the Zulu time
        utc_time = datetime.strptime(time_in_zulu, '%H:%M:%S')
        utc_time = utc_time.replace(tzinfo=pytz.utc)
        # Find the appropriate time zone for the given city and country
        timezone_str = get_timezone(target_city, target_country)
        local_timezone = pytz.timezone(timezone_str)
        # Convert UTC time to local time
        local_time = utc_time.astimezone(local_timezone)
        result = local_time.strftime('%H:%M:%S')
    except:
        pass
    return result


def get_timezone(city, country):
    city_country_to_timezone = {
        ('Melbourne', 'Australia'): 'Australia/Melbourne',
        ('Kuala Lumpur', 'Malaysia'): 'Asia/Kuala_Lumpur',
        ('Shanghai', 'China'): 'Asia/Shanghai',
        ('Sakhir', 'Bahrain'): 'Asia/Bahrain',
        ('Montmeló', 'Spain'): 'Europe/Madrid',  # Assuming nearest major city timezone
        ('Monte-Carlo', 'Monaco'): 'Europe/Monaco',
        ('Montreal', 'Canada'): 'America/Montreal',
        ('Spielberg', 'Austria'): 'Europe/Vienna',  # Assuming nearest major city timezone
        ('Silverstone', 'UK'): 'Europe/London',
        ('Budapest', 'Hungary'): 'Europe/Budapest',
        ('Spa', 'Belgium'): 'Europe/Brussels',  # Assuming nearest major city timezone
        ('Monza', 'Italy'): 'Europe/Rome',  # Assuming nearest major city timezone
        ('Marina Bay', 'Singapore'): 'Asia/Singapore',
        ('Suzuka', 'Japan'): 'Asia/Tokyo',  # Assuming nearest major city timezone
        ('Sochi', 'Russia'): 'Europe/Moscow',
        ('Austin', 'USA'): 'America/Chicago',
        ('Mexico City', 'Mexico'): 'America/Mexico_City',
        ('São Paulo', 'Brazil'): 'America/Sao_Paulo',
        ('Abu Dhabi', 'UAE'): 'Asia/Dubai',
        ('Baku', 'Azerbaijan'): 'Asia/Baku',
        ('Hockenheim', 'Germany'): 'Europe/Berlin',
        ('Le Castellet', 'France'): 'Europe/Paris',  # Assuming nearest major city timezone
        ('Mugello', 'Italy'): 'Europe/Rome',  # Assuming nearest major city timezone
        ('Nürburg', 'Germany'): 'Europe/Berlin',  # Assuming nearest major city timezone
        ('Portimão', 'Portugal'): 'Europe/Lisbon',
        ('Imola', 'Italy'): 'Europe/Rome',
        ('Istanbul', 'Turkey'): 'Europe/Istanbul',
        ('Zandvoort', 'Netherlands'): 'Europe/Amsterdam',
        ('Al Daayen', 'Qatar'): 'Asia/Qatar',
        ('Jeddah', 'Saudi Arabia'): 'Asia/Riyadh',
        ('Miami', 'USA'): 'America/New_York',
        ('Las Vegas', 'United States'): 'America/Los_Angeles',
        ('Uttar Pradesh', 'India'): 'Asia/Kolkata',
        ('Yeongam County', 'Korea'): 'Asia/Seoul',
        ('Valencia', 'Spain'): 'Europe/Madrid',
        ('Oyama', 'Japan'): 'Asia/Tokyo',
        ('Magny Cours', 'France'): 'Europe/Paris',
        ('Indianapolis', 'USA'): 'America/Indiana/Indianapolis',
    }
    # Attempt to get the timezone from the dictionary
    timezone = city_country_to_timezone.get((city, country))
    # If the timezone is not found, use UTC as a default
    if timezone is None:
        print(f"Timezone for {city}, {country} not found. Using UTC as default.")
        return 'UTC'
    return timezone

# ============
# merge df
# ============
# df1 = pd.merge(races, weather_info, how='inner', on=['season', 'round', 'circuit_id']).drop(['url'], axis=1)
# df2 = pd.merge(df1, results, how='inner', on=['season', 'round', 'circuit_id'])
# df3 = pd.merge(df2, driver_standings, how='left', on=['season', 'round', 'driver']) 
# df4 = pd.merge(df3, constructor_standings, how='left', on=['season', 'round', 'constructor']) #from 1958
# df5 = pd.merge(df4, qualifying_results, how='inner', on=['season', 'round', 'grid'])
# display(results)
results.drop(columns=['grid'], inplace=True)
results["driver_name"] = results["driver_name"].replace("kimi räikkönen", "kimi raikkonen")
results["driver_name"] = results["driver_name"].replace("alexander albon", "alex albon")
results["driver_name"] = results["driver_name"].replace("nico hülkenberg", "nico hulkenberg")
results["driver_name"] = results["driver_name"].replace("sergio pérez", "sergio perez")
results["driver_name"] = results["driver_name"].replace("zhou guanyu", "guanyu zhou")
results["driver_name"] = results["driver_name"].replace("esteban gutiérrez", "esteban gutierrez")
qualifying_results["driver_name"] = qualifying_results["driver_name"].replace("kimi räikkönen", "kimi raikkonen")
qualifying_results["driver_name"] = qualifying_results["driver_name"].replace("alexander albon", "alex albon")
qualifying_results["driver_name"] = qualifying_results["driver_name"].replace("nico hülkenberg", "nico hulkenberg")
qualifying_results["driver_name"] = qualifying_results["driver_name"].replace("sergio pérez", "sergio perez")
qualifying_results["driver_name"] = qualifying_results["driver_name"].replace("zhou guanyu", "guanyu zhou")
qualifying_results["driver_name"] = qualifying_results["driver_name"].replace("esteban gutiérrez", "esteban gutierrez")
# display(results)
temp_df = pd.merge(results, races, how='left', on=['season', 'round', 'circuit_id']).drop(['url'], axis=1)
temp_df = pd.merge(temp_df, driver_standings, how='left', on=['season', 'round', 'driver']) 
temp_df = pd.merge(temp_df, qualifying_results, how='left', on=['season', 'round', 'driver_name'])
temp_df = pd.merge(temp_df, constructor_standings, how='left', on=['season', 'round', 'constructor'])
temp_df = pd.merge(temp_df, weather_info, how='left', on=['season', 'round', 'circuit_id'])

# display(temp_df)
temp_df.to_csv("./data/temp_df.csv", index=False)

circuit_elevation = pd.read_csv("./more_db/circuit_elevation.csv")
# constructor_names_df = pd.read_csv("./more_db/constructor_names.csv")
# driver_names_df = pd.read_csv("./more_db/driver_names.csv")
# start_times_df = pd.read_csv("./more_db/start_times.csv")


# merging more_db into final_df
new_df1 = pd.merge(temp_df, circuit_elevation, how="left", on="circuit_id")
# new_df1["driver_name"] = new_df1["driver_name"].replace("kimi räikkönen", "kimi raikkonen")
# new_df1["driver_name"] = new_df1["driver_name"].replace("alexander albon", "alex albon")
new_df1.rename(columns = {
    'lat':'circuit_lat',
    'long':'circuit_long',
    'nationality':'driver_nationality',
    }, inplace = True)

autosport_df.rename(columns = {
    'qualifying_sprint_position':'sprint_qualifying_position', 
    'qualifying_sprint_time':'sprint_qualifying_time',
    }, inplace = True)
autosport_df.loc[autosport_df["has_sprint"].isnull(), "has_sprint"] = False

autosport_df["driver_name"] = autosport_df["driver_name"].replace("zhou guanyu", "guanyu zhou")

final_df = pd.merge(new_df1, autosport_df, how="outer", on=["driver_name", "season", "round"])
# final_df = pd.merge(new_df1, constructor_names_df, how="left", on="constructor")
# final_df = pd.merge(new_df2, driver_names_df, how="left", on="driver")
# final_df = pd.merge(new_df2, start_times_df, how="left", on=["season", "round", "circuit_id"])

# print(len(final_df.columns))
final_df.drop(columns=['circuit_lat', 'circuit_long', 'constructor', 'driver', 'weather', 'grid', 'car'], inplace=True)

final_df["start_time"] = final_df["start_time"].astype(str).apply(strip_z)

for row in final_df.itertuples():
    final_df.at[row.Index, 'start_time'] = get_local_time(final_df.at[row.Index, 'circuit_city'], final_df.at[row.Index, 'circuit_country'], final_df.at[row.Index, 'start_time'])
    # row['start_time'] = get_local_time(row['circuit_city'], row['circuit_country'], row['start_time'])

new_order = [
    'season',
    'round',
    'date',
    'start_time',
    'driver_name',
    'date_of_birth',
    'driver_nationality',
    'driver_points',
    'driver_standings_pos',
    'driver_wins',
    'initial_tyre',
    'qualifying_position',
    'qualifying_time',
    'circuit_id',
    'circuit_name',
    'circuit_elevation',
    'circuit_city',
    'circuit_country',
    'constructor_name',
    'constructor_country',
    'constructor_points',
    'constructor_standings_pos',
    'constructor_wins',
    'fp_pos_1',
    'fp_time_1',
    'fp_pos_2',
    'fp_time_2',
    'fp_pos_3',
    'fp_time_3',
    'weather_cloudy',
    'weather_cold',
    'weather_dry',
    'weather_warm',
    'weather_wet',
    'has_sprint',
    'sprint_qualifying_position',
    'sprint_qualifying_time',
    'sprint_fl_pos',
    'sprint_fl_time',
    'sprint_laps',
    'sprint_position',
    'sprint_time',
    'podium',
    'num_o_ps',
    'time',
    'status',
    'fl_pos',
    'fl_time',
    'points',
]
# print(len(new_order))
final_df = final_df[new_order]
final_df = final_df.dropna(subset=['podium'])

final_df.to_csv("./data/final_df.csv", sep=",", index=False)

# %%
import pandas as pd

final_df = pd.read_csv("./data/final_df.csv")
display(final_df)
# display(final_df['circuit_city'])
# print(final_df.at[0, 'circuit_city'])

# count number of empty cells in the column qualifying_time
print(f"qualifying_position: {final_df['qualifying_position'].isnull().sum()}")
print(f"qualifying_time: {final_df['qualifying_time'].isnull().sum()}")
print(f"sprint_qualifying_position: {final_df['sprint_qualifying_position'].isnull().sum()}")
print(f"sprint_qualifying_time: {final_df['sprint_qualifying_time'].isnull().sum()}")
print(f"fp_pos_1: {final_df['fp_pos_1'].isnull().sum()}")
print(f"fp_time_1: {final_df['fp_time_1'].isnull().sum()}")
print(f"fp_pos_2: {final_df['fp_pos_2'].isnull().sum()}")
print(f"fp_time_2: {final_df['fp_time_2'].isnull().sum()}")
print(f"fp_pos_3: {final_df['fp_pos_3'].isnull().sum()}")
print(f"fp_time_3: {final_df['fp_time_3'].isnull().sum()}")
print(f"sprint_fl_pos: {final_df['sprint_fl_pos'].isnull().sum()}")
print(f"sprint_fl_time: {final_df['sprint_fl_time'].isnull().sum()}")
print(f"sprint_laps: {final_df['sprint_laps'].isnull().sum()}")
print(f"sprint_position: {final_df['sprint_position'].isnull().sum()}")
print(f"sprint_time: {final_df['sprint_time'].isnull().sum()}")
print(f"fl_pos: {final_df['fl_pos'].isnull().sum()}")
print(f"fl_time: {final_df['fl_time'].isnull().sum()}")

# Before
# qualifying_position: 149
# qualifying_time: 298
# sprint_qualifying_position: 3621
# sprint_qualifying_time: 3631
# fp_pos_1: 194
# fp_time_1: 321
# fp_pos_2: 258
# fp_time_2: 325
# fp_pos_3: 343
# fp_time_3: 431
# sprint_fl_pos: 3643
# sprint_fl_time: 3643
# sprint_laps: 3620
# sprint_laps: 3500
# sprint_position: 
# sprint_time: 
# fl_pos: 
# fl_time: 

# After
# qualifying_position: 149
# qualifying_time: 278
# sprint_qualifying_position: 3501
# sprint_qualifying_time: 3514
# fp_pos_1: 194
# fp_time_1: 301
# fp_pos_2: 258
# fp_time_2: 306
# fp_pos_3: 343
# fp_time_3: 411
# sprint_fl_pos: 3526
# sprint_fl_time: 3526
# sprint_laps: 3500
# sprint_position: 3500
# sprint_time: 3505
# fl_pos: 188
# fl_time: 188
# Out:
#       season  round        date start_time       driver_name date_of_birth  \
# 0       2015      1  2015-03-15   14:40:00    lewis hamilton    1985-01-07
# 1       2015      1  2015-03-15   14:40:00      nico rosberg    1985-06-27
# 2       2015      1  2015-03-15   14:40:00  sebastian vettel    1987-07-03
# 3       2015      1  2015-03-15   14:40:00      felipe massa    1981-04-25
# 4       2015      1  2015-03-15   14:40:00       felipe nasr    1992-08-21
# ...      ...    ...         ...        ...               ...           ...
# 3735    2023     22  2023-11-26   16:41:00    logan sargeant    2000-12-31
# 3736    2023     22  2023-11-26   16:41:00       guanyu zhou    1999-05-30
# 3737    2023     22  2023-11-26   16:41:00      carlos sainz    1994-09-01
# 3738    2023     22  2023-11-26   16:41:00   valtteri bottas    1989-08-28
# 3739    2023     22  2023-11-26   16:41:00   kevin magnussen    1992-10-05
#
#      driver_nationality  driver_points  driver_standings_pos  driver_wins  \
# 0               British            0.0                   0.0          0.0
# 1                German            0.0                   0.0          0.0
# 2                German            0.0                   0.0          0.0
# 3             Brazilian            0.0                   0.0          0.0
# 4             Brazilian            0.0                   0.0          0.0
# ...                 ...            ...                   ...          ...
# 3735           American            1.0                  21.0          0.0
# 3736            Chinese            6.0                  18.0          0.0
# 3737            Spanish          200.0                   4.0          1.0
# 3738            Finnish           10.0                  15.0          0.0
# 3739             Danish            3.0                  19.0          0.0
#
#       ... sprint_laps  sprint_position  sprint_time podium num_o_ps  \
# 0     ...         NaN              NaN          NaN    1.0      2.0
# 1     ...         NaN              NaN          NaN    2.0      2.0
# 2     ...         NaN              NaN          NaN    3.0      2.0
# 3     ...         NaN              NaN          NaN    4.0      2.0
# 4     ...         NaN              NaN          NaN    5.0      2.0
# ...   ...         ...              ...          ...    ...      ...
# 3735  ...         NaN              NaN          NaN   16.0      NaN
# 3736  ...         NaN              NaN          NaN   17.0      NaN
# 3737  ...         NaN              NaN          NaN   18.0      NaN
# 3738  ...         NaN              NaN          NaN   19.0      NaN
# 3739  ...         NaN              NaN          NaN   20.0      NaN
#
#            time    status fl_pos  fl_time points
# 0     5514067.0  Finished    1.0  90945.0   25.0
# 1     5515427.0  Finished    2.0  91092.0   18.0
# 2     5548590.0  Finished    4.0  91457.0   15.0
# 3     5552263.0  Finished    6.0  91719.0   12.0
# 4     5609216.0  Finished    9.0  92612.0   10.0
# ...         ...       ...    ...      ...    ...
# 3735  5310415.0  Finished    NaN      NaN    0.0
# 3736  5312046.0  Finished    NaN      NaN    0.0
# 3737        NaN   Retired    NaN      NaN    0.0
# 3738        NaN    +1 Lap    NaN      NaN    0.0
# 3739        NaN    +1 Lap    NaN      NaN    0.0
#
# [3740 rows x 49 columns]
# qualifying_position: 149
# qualifying_time: 278
# sprint_qualifying_position: 3501
# sprint_qualifying_time: 3514
# fp_pos_1: 194
# fp_time_1: 301
# fp_pos_2: 258
# fp_time_2: 306
# fp_pos_3: 343
# fp_time_3: 411
# sprint_fl_pos: 3526
# sprint_fl_time: 3526
# sprint_laps: 3500
# sprint_position: 3500
# sprint_time: 3505
# fl_pos: 188
# fl_time: 188
